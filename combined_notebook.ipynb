# %% [markdown]
# # Spam Detection Pipeline
#
# This notebook runs the full spam detection pipeline used for the assignment:
# 1. Combine and clean multiple message sources (SMS, email, mixed, YouTube, reviews).
# 2. Preprocess and balance the data for downstream models.
# 3. Feature engineering for K-Means, XGBoost and BiLSTM models.
# 4. Experiments and model training: K-Means parameter sweeps, XGBoost hyperparameter search, and BiLSTM experiments.
# 5. Evaluation and visual analysis of model performance and feature importance.
#
# Notebook structure and where each major step is implemented in the code are noted in the cells below. See the code cells for exact function names and parameters.

# %% [markdown]
# ## 1. Setup and imports
#
# This cell loads required Python libraries and project modules. GPU memory is cleared where appropriate to avoid allocation conflicts when training multiple models sequentially. If you run on a CPU-only machine, the notebook will fall back gracefully.
#
# Key modules:
# - Data combination and base preprocessing functions used to create train and test data in `final_dataset` folder.
# - Model training wrappers for K-Means, XGBoost and LSTM that are called later in the notebook.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import time
from pathlib import Path
import torch
from pathlib import Path

# Custom modules
from src.base_preprocessing.combine import combine_datasets
from src.base_preprocessing.clean import run_base_preprocessing_pipeline

from src.kmeans.feature_engineer import engineer_features
from src.kmeans.train import train_kmeans
from src.kmeans.model import KMeansTextInferencer

from src.xgb.feature_engineer import engineer_ml_features
from src.xgb.train import train_xgboost_model
from src.xgb.model import XGBTextClassifier

from src.lstm.preprocessing import run_lstm_preprocessing
from src.lstm.train import run_lstm_experiments
from src.lstm.model import LSTMTextClassifier

# %% [markdown]
# ## 2. Combine datasets and base preprocessing
#
# This step merges the SMS, email, mixed, YouTube and review sources into a unified CSV, then runs the base preprocessing pipeline that:
# - normalizes labels to binary spam/ham
# - performs token replacements for URLs, emails, phones
# - balances and splits the dataset into train and test sets
#
# The main invocations are `combine_datasets(...)` and `run_base_preprocessing_pipeline(...)`. Check that the produced files are in `final_dataset` folder before continuing.

# %%
file_paths = {
    "sms": "datasets/sms/sms.csv",
    "email": "datasets/email/email.csv",
    "mix": "datasets/mix_email_sms/mix.csv",
    "youtube": "datasets/comment/youtube_comments.csv",
    "review": "datasets/review/review.jsonl",
}

combine_datasets(file_paths, output_path="datasets/combined.csv")
# Out:
# Starting data combination process...
# ==================================================
# Loaded 5572 SMS records
# Loaded 5728 email records
# Loaded 8175 mixed email/SMS records
# Loaded 1956 YouTube comment records
# Warning: datasets/review/review.jsonl not found
#
# ==================================================
# Combining datasets...
#
# ==================================================
# Dataset Summary:
# Total records: 21431
#
# Records by source:
#   mix_email_sms: 8175
#   email: 5728
#   sms: 5572
#   youtube: 1956
#
# Label distribution (0=ham, 1=spam):
#   0: 14186
#   1: 7245
#
# Spam rate by source:
#   sms: 13.4% (747/5572)
#   email: 23.9% (1368/5728)
#   mix_email_sms: 50.5% (4125/8175)
#   youtube: 51.4% (1005/1956)
#
# Overall spam rate: 33.8%
#
# Combined dataset saved to: datasets/combined.csv
# Final dataset shape: (21431, 3)
#
# Sample of combined data:
#                                                                                                                                                           text  label source
# 0                                              Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...      0    sms
# 1                                                                                                                                Ok lar... Joking wif u oni...      0    sms
# 2  Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's      1    sms
# 3                                                                                                            U dun say so early hor... U c already then say...      0    sms
# 4                                                                                                Nah I don't think he goes to usf, he lives around here though      0    sms

# %% [markdown]
# This stage cleans and balances the combined dataset to ensure a representative spam ratio across sources.
# The `run_base_preprocessing_pipeline` function:
# - Applies text normalization and token replacements (`<URL>`, `<EMAIL>`, etc.)
# - Balances datasets by adjusting spam ratios per source
# - Splits the data into training and testing sets (default 85/15)
# - Saves preprocessed files to `final_dataset`

# %%
target_spam_rates = {
    "sms": 0.3,
    "email": 0.35,
    "mix_email_sms": None,  # Keep original
    "youtube": None,  # Keep original
}

success = run_base_preprocessing_pipeline(
    target_spam_rates=target_spam_rates,
    input_path="datasets/combined.csv",
    test_size=0.15,
    soft_cap_ratio=0.35,
    output_dir="final_dataset"
)

if success:
    print("\n Preprocessing pipeline completed successfully!")
else:
    print("\n Preprocessing failed. Check error messages above.")
# Out:
# STARTING BASE PREPROCESSING PIPELINE
# ============================================================
# Strategy:
#   1. Stratified split by source and label (80/20)
#   2. Rebalance training data only:
#      - sms/email: undersample ham to achieve 35-40% spam
#      - mix_email_sms/youtube: keep original spam/ham ratio
#   3. Apply soft cap: each source ≤40-45% of total training samples
# ============================================================
# ============================================================
# LOADING AND ANALYZING DATA
# ============================================================
# Loaded 21,431 records
#
# Dataset shape: (21431, 3)
# Columns: ['text', 'label', 'source']
#
# Source Distribution:
#   mix_email_sms: 8,175 (38.15%)
#   email: 5,728 (26.73%)
#   sms: 5,572 (26.0%)
#   youtube: 1,956 (9.13%)
#
# Spam Rate by Source:
#   sms: 13.4% (747/5,572)
#   email: 23.9% (1,368/5,728)
#   mix_email_sms: 50.5% (4,125/8,175)
#   youtube: 51.4% (1,005/1,956)
#
# Overall spam rate: 33.8%
#
# ============================================================
# TEXT CLEANING
# ============================================================
# Cleaning text data...
# Removed 18 invalid records
# Text cleaning completed. Final dataset: 21,413 records
#
# ============================================================
# CREATING STRATIFIED TRAIN/TEST SPLITS
# ============================================================
# Original distribution by source and label:
#   email_ham: 4,360 records
#   email_spam: 1,368 records
#   mix_email_sms_ham: 4,049 records
#   mix_email_sms_spam: 4,125 records
#   sms_ham: 4,819 records
#   sms_spam: 747 records
#   youtube_ham: 940 records
#   youtube_spam: 1,005 records
#
# Data splits created:
#   Training: 18,201 records (85.0%)
#   Test:     3,212 records (15.0%)
#
# Overall spam rate verification:
#   Original: 33.8% spam
#   Training: 33.8% spam
#   Test:     33.8% spam
#
# Source distribution verification:
#   Original:
#     mix_email_sms: 38.2%
#     email: 26.8%
#     sms: 26.0%
#     youtube: 9.1%
#   Training:
#     mix_email_sms: 38.2%
#     email: 26.8%
#     sms: 26.0%
#     youtube: 9.1%
#   Test:
#     mix_email_sms: 38.2%
#     email: 26.7%
#     sms: 26.0%
#     youtube: 9.1%
#
# Spam rate by source verification:
#   sms: Original=13.4%, Train=13.4%, Test=13.4%
#   email: Original=23.9%, Train=23.9%, Test=23.9%
#   mix_email_sms: Original=50.5%, Train=50.5%, Test=50.5%
#   youtube: Original=51.7%, Train=51.7%, Test=51.7%
#
# Stratified splits completed successfully!
#
# ============================================================
# REBALANCING TRAINING DATA
# ============================================================
# Original training distribution:
#   mix_email_sms: 6,948 total, 50.5% spam
#   youtube: 1,653 total, 51.7% spam
#   sms: 4,731 total, 13.4% spam
#   email: 4,869 total, 23.9% spam
#
# Rebalancing sources...
# Target spam rates: {'sms': 0.3, 'email': 0.35, 'mix_email_sms': None, 'youtube': None}
#   Processing mix_email_sms: target_spam_rate = None (type: <class 'NoneType'>)
#   mix_email_sms: Keeping original ratio (50.5% spam)
#   Processing youtube: target_spam_rate = None (type: <class 'NoneType'>)
#   youtube: Keeping original ratio (51.7% spam)
#   Processing sms: target_spam_rate = 0.3 (type: <class 'float'>)
#   sms: 4,731 → 2,116 (30.0% spam)
#   Processing email: target_spam_rate = 0.35 (type: <class 'float'>)
#   email: 4,869 → 3,322 (35.0% spam)
#
# Applying soft cap (35% max per source)...
#   mix_email_sms: 6,948 → 4,912 (capped)
#   youtube: 1,653 (no cap needed)
#   sms: 2,116 (no cap needed)
#   email: 3,322 (no cap needed)
#
# Training data rebalancing completed:
#   Original: 18,201 records
#   Rebalanced: 12,003 records
#   Overall spam rate: 42.7%
#
# Final training distribution:
#   mix_email_sms: 4,912 (40.9% of total, 50.5% spam)
#   youtube: 1,653 (13.8% of total, 51.7% spam)
#   sms: 2,116 (17.6% of total, 30.0% spam)
#   email: 3,322 (27.7% of total, 35.0% spam)
#
# ============================================================
# SETTING UP 5-FOLD CROSS-VALIDATION
# ============================================================
# Verifying fold balance:
#   Fold 1: Train=9,602 (42.8% spam), Val=2,401 (42.7% spam)
#   Fold 2: Train=9,602 (42.8% spam), Val=2,401 (42.7% spam)
#   Fold 3: Train=9,602 (42.8% spam), Val=2,401 (42.7% spam)
#   Fold 4: Train=9,603 (42.7% spam), Val=2,400 (42.8% spam)
#   Fold 5: Train=9,603 (42.7% spam), Val=2,400 (42.8% spam)
#
# K-fold setup completed. Use StratifiedKFold with stratify_labels in your model training.
#
# ============================================================
# SAVING PREPROCESSED DATA
# ============================================================
# Data saved to: final_dataset
# Files created:
#   - train.csv (12,003 records)
#   - test.csv (3,212 records)
#   - metadata.json (preprocessing statistics)
#
# ============================================================
# CREATING BALANCE ANALYSIS PLOTS
# ============================================================
# Balance analysis plots saved: final_dataset\balance_analysis.png
#
# ============================================================
# BASE PREPROCESSING PIPELINE COMPLETED!
# ============================================================
# Original dataset: 21,413 records
# Training set: 12,003 records (rebalanced, ready for 5-fold CV)
# Test set: 3,212 records (original distribution preserved)
# Output directory: final_dataset
#
# Final training data composition:
#   mix_email_sms: 4,912 samples (40.9% of total, 50.5% spam)
#   youtube: 1,653 samples (13.8% of total, 51.7% spam)
#   sms: 2,116 samples (17.6% of total, 30.0% spam)
#   email: 3,322 samples (27.7% of total, 35.0% spam)
#
# Overall spam rates:
#   Training: 42.7%
#   Test: 33.8%
#
#  Preprocessing pipeline completed successfully!

# %% [markdown]
# ## 3. Feature Engineering
# Feature engineering transforms the cleaned text into numerical vectors suitable for machine learning models.
#
# The pipeline creates three main feature types:
# 1. **TF-IDF Features:** Capture keyword frequency and context.
# 2. **Statistical Features:** Text length, word count, average word size.
# 3. **Special Token Features:** Count of special markers like `<EMAIL>`, `<URL>`, and punctuation ratios.

# %%
output_dir, metadata = engineer_ml_features(
    data_path="final_dataset",
    output_dir="preprocessed/xgboost",
    max_tfidf_features=10000, 
    ngram_range=(1, 2),  # Unigrams and bigrams
)
# Out:
# Starting ML feature engineering pipeline
# ============================================================
# Loading preprocessed data...
# Training data: 12003 records
# Test data: 3212 records
# Sources found: ['email', 'mix_email_sms', 'sms', 'youtube']
# Extracting text statistics...
# Extracting text statistics...
# Extracting special character features...
# Extracting special character features...
# Extracting source features...
# Extracting source features...
# Creating TF-IDF features (max_features=10000, ngram_range=(1, 2))...
# Fitting TF-IDF on training data...
# Transforming test data...
# TF-IDF matrix shape - Train: (12003, 10000), Test: (3212, 10000)
# TF-IDF sparsity - Train: 0.0083
# TF-IDF sparsity - Test: 0.0080
# Combining all features...
# Note: Numerical features NOT scaled (appropriate for tree-based models)
# Combined feature matrix shape: (12003, 10023)
# Combined sparsity: 0.0092
# Combining all features...
# Note: Numerical features NOT scaled (appropriate for tree-based models)
# Combined feature matrix shape: (3212, 10023)
# Combined sparsity: 0.0089
# Saving features and metadata...
# Features saved to: preprocessed\xgboost_10k_bigrams
# ============================================================
# Feature Engineering Summary:
# Total features: 10,023
#   - TF-IDF features: 10,000
#   - Statistical features: 4
#   - Special character features: 15
#   - Source features: 4
# Training samples: 12,003
# Test samples: 3,212
# Matrix sparsity: 0.0092
# Optimizations applied:
#   - No stop word removal (preserves spam indicators)
#   - Special tokens preserved in TF-IDF
#   - No numerical feature scaling (tree-model appropriate)
#   - Sublinear TF scaling applied
# Features saved to: preprocessed\xgboost_10k_bigrams

# %% [markdown]
# ## 4. XGBoost Classification
# XGBoost is used as a supervised model optimized for high accuracy and explainability.
#
# The process includes:
# 1. **Randomized Hyperparameter Search:** Finds optimal parameters using cross-validation with AUCPR as the metric.
# 2. **Retraining with Early Stopping:** Fine-tunes the best model with larger iterations and early stopping to prevent overfitting.
# 3. **Threshold Optimization:** Chooses the F1-optimal decision threshold instead of the default 0.5 for better balance between precision and recall.
# 4. **Evaluation:** Assesses model performance across sources and generates feature importance plots.

# %%
model, results = train_xgboost_model(
    features_dir="xgboost",
    output_dir="models/xgboost",
    cv_folds=5,  # 5-fold cross-validation
    n_iter=500,  # Number of random parameter combinations
    random_state=36,  # For reproducibility
    verbose=1,  # Show training progress
)

print("\n XGBoost training pipeline completed!")
print("Key results:")
print(f"- Best parameters: {results['best_parameters']}")
print(f"- Cross-validation F1: {results['best_cv_score']:.4f}")
print(f"- Test set F1: {results['test_metrics']['f1']:.4f}")
print(f"- Test set Accuracy: {results['test_metrics']['accuracy']:.4f}")
print(f"- GPU acceleration: {results['optimization']['gpu_used']}")
print(f"- Parameter combinations tested: {results['n_iter']}")
# Out:
# Redirecting to new AUCPR-based training pipeline...
# Starting XGBoost training pipeline with AUCPR optimization and early stopping
# ================================================================================
# âœ“ GPU is available and working with XGBoost
# Loading engineered features...
# Training features: (12003, 10023)
# Test features: (3212, 10023)
# Total features: 10,023
# Training samples: 12,003
# Test samples: 3,212
#
# Dataset class distribution:
# Training: 6,872 negative, 5,131 positive (42.7% spam)
# Test: 2,125 negative, 1,087 positive (33.8% spam)
# Class ratio (neg/pos): 1.339
# Setting up 5-fold cross-validation with source+label stratification...
# Stratification groups found:
#   email_0: 2159 samples
#   email_1: 1163 samples
#   mix_email_sms_0: 2433 samples
#   mix_email_sms_1: 2479 samples
#   sms_0: 1481 samples
#   sms_1: 635 samples
#   youtube_0: 799 samples
#   youtube_1: 854 samples
#
# Fold balance verification:
# Fold 1:
#   Spam rates - Train: 0.428, Val: 0.427
#   Val source dist: mix_email_sms: 0.41, email: 0.28, sms: 0.18, youtube: 0.14
# Fold 2:
#   Spam rates - Train: 0.428, Val: 0.427
#   Val source dist: mix_email_sms: 0.41, email: 0.28, sms: 0.18, youtube: 0.14
# Fold 3:
#   Spam rates - Train: 0.428, Val: 0.427
#   Val source dist: mix_email_sms: 0.41, email: 0.28, sms: 0.18, youtube: 0.14
# Fold 4:
#   Spam rates - Train: 0.427, Val: 0.428
#   Val source dist: mix_email_sms: 0.41, email: 0.28, sms: 0.18, youtube: 0.14
# Fold 5:
#   Spam rates - Train: 0.427, Val: 0.427
#   Val source dist: mix_email_sms: 0.41, email: 0.28, sms: 0.18, youtube: 0.14
# Defining XGBoost parameter distributions for RandomizedSearchCV...
# Configuring for GPU training...
# Parameter distributions prepared (key summary):
#   objective: ['binary:logistic']
#   eval_metric: ['aucpr']
#   random_state: [42]
#   verbosity: [0]
#   tree_method: ['gpu_hist']
#   gpu_id: [0]
#   n_estimators: distribution <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7cd1703b1e90>
#   learning_rate: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd1703f7190>
#   max_depth: distribution <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7cd1a49d0e10>
#   min_child_weight: distribution <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7cd17040c290>
#   reg_alpha: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040c490>
#   reg_lambda: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040c990>
#   subsample: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040cf10>
#   colsample_bytree: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040d450>
#   colsample_bylevel: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040d9d0>
#   gamma: distribution <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7cd17040df50>
#   max_delta_step: [0, 1, 2]
#
# Step 1: Hyperparameter search using average_precision (AUCPR)...
# Starting XGBoost randomized search with average_precision scoring...
# Testing 500 random parameter combinations
# Using 5-fold cross-validation with source+label stratification
# Original grid search would test ~1000 combinations
# Randomized search will test 500 combinations (~50.0% of original)
# Randomized search started at: 2025-09-28 02:10:02
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# XGBoost randomized search completed in: 148.06 minutes
# Average time per parameter combination: 17.77 seconds
# Analyzing XGBoost randomized search results...
# Best cross-validation score: 0.9497
# Best parameters:
#   colsample_bylevel: 0.5320836894770028
#   colsample_bytree: 0.6215201425313747
#   eval_metric: aucpr
#   gamma: 0.8350523138957243
#   gpu_id: 0
#   learning_rate: 0.011288034009058942
#   max_delta_step: 1
#   max_depth: 9
#   min_child_weight: 1
#   n_estimators: 173
#   objective: binary:logistic
#   random_state: 42
#   reg_alpha: 0.00438149149150876
#   reg_lambda: 0.02131232878302273
#   subsample: 0.7287830312169208
#   tree_method: gpu_hist
#   verbosity: 0
#
# Top 10 parameter combinations:
# Score: 0.9497 (+/- 0.0104) - {'colsample_bylevel': 0.5320836894770028, 'colsample_bytree': 0.6215201425313747, 'eval_metric': 'aucpr', 'gamma': 0.8350523138957243, 'gpu_id': 0, 'learning_rate': 0.011288034009058942, 'max_delta_step': 1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 173, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.00438149149150876, 'reg_lambda': 0.02131232878302273, 'subsample': 0.7287830312169208, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9496 (+/- 0.0095) - {'colsample_bylevel': 0.5677396159359247, 'colsample_bytree': 0.5081931623464495, 'eval_metric': 'aucpr', 'gamma': 0.23801692829966536, 'gpu_id': 0, 'learning_rate': 0.0025630215331373337, 'max_delta_step': 1, 'max_depth': 8, 'min_child_weight': 2, 'n_estimators': 995, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 3.139067541685405e-05, 'reg_lambda': 5.775593677052135, 'subsample': 0.7351917055228403, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9449 (+/- 0.0073) - {'colsample_bylevel': 0.5506190727338252, 'colsample_bytree': 0.5469912948625404, 'eval_metric': 'aucpr', 'gamma': 0.4516927299449929, 'gpu_id': 0, 'learning_rate': 0.005441558761497183, 'max_delta_step': 1, 'max_depth': 11, 'min_child_weight': 4, 'n_estimators': 727, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.0003777487039414822, 'reg_lambda': 0.0505847293434774, 'subsample': 0.7326801688213145, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9430 (+/- 0.0122) - {'colsample_bylevel': 0.5308189529156907, 'colsample_bytree': 0.6058978119557228, 'eval_metric': 'aucpr', 'gamma': 0.7316594547876364, 'gpu_id': 0, 'learning_rate': 0.002403984150053491, 'max_delta_step': 1, 'max_depth': 9, 'min_child_weight': 2, 'n_estimators': 501, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 3.6296835838667447, 'reg_lambda': 0.0013745219775820581, 'subsample': 0.939577837067158, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9415 (+/- 0.0135) - {'colsample_bylevel': 0.5355753997140762, 'colsample_bytree': 0.506013126384177, 'eval_metric': 'aucpr', 'gamma': 0.4530020789150627, 'gpu_id': 0, 'learning_rate': 0.003275611637710083, 'max_delta_step': 2, 'max_depth': 7, 'min_child_weight': 7, 'n_estimators': 150, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.006795222800132425, 'reg_lambda': 0.11072974527270787, 'subsample': 0.8708301560287814, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9409 (+/- 0.0127) - {'colsample_bylevel': 0.850364872580442, 'colsample_bytree': 0.5384103460244225, 'eval_metric': 'aucpr', 'gamma': 0.6231990913333528, 'gpu_id': 0, 'learning_rate': 0.0010335748976890008, 'max_delta_step': 2, 'max_depth': 11, 'min_child_weight': 1, 'n_estimators': 417, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.00280761090319683, 'reg_lambda': 0.34854162100448133, 'subsample': 0.6274082794531732, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9402 (+/- 0.0130) - {'colsample_bylevel': 0.665439746887269, 'colsample_bytree': 0.5411808871352841, 'eval_metric': 'aucpr', 'gamma': 0.30181696253660295, 'gpu_id': 0, 'learning_rate': 0.0015669613539607218, 'max_delta_step': 2, 'max_depth': 10, 'min_child_weight': 2, 'n_estimators': 736, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.0007091666915333263, 'reg_lambda': 8.720343092446079, 'subsample': 0.6530676874445887, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9379 (+/- 0.0088) - {'colsample_bylevel': 0.5672551889151252, 'colsample_bytree': 0.5499012722704775, 'eval_metric': 'aucpr', 'gamma': 0.3349813549182119, 'gpu_id': 0, 'learning_rate': 0.0072318090665227696, 'max_delta_step': 1, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 847, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.006445448355624091, 'reg_lambda': 6.357935575335119, 'subsample': 0.6380199794651321, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9376 (+/- 0.0096) - {'colsample_bylevel': 0.7090750188917296, 'colsample_bytree': 0.61570333416256, 'eval_metric': 'aucpr', 'gamma': 0.7210806551988104, 'gpu_id': 0, 'learning_rate': 0.0019497781034143171, 'max_delta_step': 2, 'max_depth': 8, 'min_child_weight': 1, 'n_estimators': 706, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 2.0979914325833275e-08, 'reg_lambda': 0.08981004797905434, 'subsample': 0.5974433539440802, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Score: 0.9369 (+/- 0.0078) - {'colsample_bylevel': 0.5322880592756384, 'colsample_bytree': 0.6460039399264451, 'eval_metric': 'aucpr', 'gamma': 0.7115189831114259, 'gpu_id': 0, 'learning_rate': 0.006933146011173551, 'max_delta_step': 2, 'max_depth': 11, 'min_child_weight': 4, 'n_estimators': 291, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.018244252576893508, 'reg_lambda': 0.012126815204460729, 'subsample': 0.7770450133047202, 'tree_method': 'gpu_hist', 'verbosity': 0}
#
# Parameter analysis from top 20 combinations:
#   colsample_bylevel: avg=0.626 (+/- 0.097)
#   colsample_bytree: avg=0.613 (+/- 0.110)
#   eval_metric: [('aucpr', 20)]
#   gamma: avg=0.561 (+/- 0.253)
#   gpu_id: avg=0.000 (+/- 0.000)
#   learning_rate: avg=0.006 (+/- 0.006)
#   max_delta_step: avg=1.350 (+/- 0.477)
#   max_depth: avg=8.900 (+/- 1.758)
#   min_child_weight: avg=3.900 (+/- 2.755)
#   n_estimators: avg=466.700 (+/- 263.574)
#   objective: [('binary:logistic', 20)]
#   random_state: avg=42.000 (+/- 0.000)
#   reg_alpha: avg=0.332 (+/- 0.869)
#   reg_lambda: avg=1.583 (+/- 2.824)
#   subsample: avg=0.768 (+/- 0.121)
#   tree_method: [('gpu_hist', 20)]
#   verbosity: avg=0.000 (+/- 0.000)
#
# Step 2: Retraining with early stopping...
#
# ============================================================
# RETRAINING WITH EARLY STOPPING
# ============================================================
# Creating 10% validation split stratified by source+label...
# Training split: 10,802 samples
# Validation split: 1,201 samples
# Training spam rate: 42.7%
# Validation spam rate: 42.8%
# Validation source distribution:
#   mix_email_sms: 40.9%
#   email: 27.6%
#   sms: 17.7%
#   youtube: 13.8%
#
# Retraining parameters:
#   colsample_bylevel: 0.5320836894770028
#   colsample_bytree: 0.6215201425313747
#   eval_metric: aucpr
#   gamma: 0.8350523138957243
#   gpu_id: 0
#   learning_rate: 0.011288034009058942
#   max_delta_step: 1
#   max_depth: 9
#   min_child_weight: 1
#   n_estimators: 2000
#   objective: binary:logistic
#   random_state: 42
#   reg_alpha: 0.00438149149150876
#   reg_lambda: 0.02131232878302273
#   subsample: 0.7287830312169208
#   tree_method: gpu_hist
#   verbosity: 0
#   early_stopping_rounds: 50
#
# Training with early stopping (patience=50)...
# Training set shape: (10802, 10023)
# Validation set shape: (1201, 10023)
# Training labels shape: (10802,)
# Validation labels shape: (1201,)
# Training stopped at iteration: 231
# Best validation aucpr: 0.8925
#
# Finding F1-optimal threshold on validation set...
# Finding optimal threshold for F1 score...
# Optimal threshold: 0.5070
# Best F1 score: 0.8818
# At optimal threshold:
#   Precision: 0.9091
#   Recall: 0.8560
#   F1: 0.8818
#
# Validation performance comparison:
# Default threshold (0.5):
#   ACCURACY: 0.8984
#   PRECISION: 0.9016
#   RECALL: 0.8560
#   F1: 0.8782
#   ROC_AUC: 0.9515
#   AUCPR: 0.9476
#
# Optimal threshold (0.5070):
#   ACCURACY: 0.9017
#   PRECISION: 0.9091
#   RECALL: 0.8560
#   F1: 0.8818
#   ROC_AUC: 0.9515
#   AUCPR: 0.9476
#
# F1 improvement: +0.0035 (+0.4%)
#
# Step 3: Final evaluation with optimal threshold...
#
# Test performance comparison:
# Default threshold (0.5):
#   ACCURACY: 0.9172
#   PRECISION: 0.8623
#   RECALL: 0.8988
#   F1: 0.8802
#   ROC_AUC: 0.9647
#   AUCPR: 0.9465
#
# Optimal threshold (0.5070):
#   ACCURACY: 0.9178
#   PRECISION: 0.8658
#   RECALL: 0.8960
#   F1: 0.8807
#   ROC_AUC: 0.9647
#   AUCPR: 0.9465
#
# Test F1 improvement: +0.0005 (+0.1%)
# Evaluating final XGBoost model...
# Using threshold: 0.5070
#
# Training Set Performance:
#   ACCURACY: 0.9018
#   PRECISION: 0.9031
#   RECALL: 0.8628
#   F1: 0.8825
#   ROC_AUC: 0.9565
#   AUCPR: 0.9520
#
# Test Set Performance:
#   ACCURACY: 0.9178
#   PRECISION: 0.8658
#   RECALL: 0.8960
#   F1: 0.8807
#   ROC_AUC: 0.9647
#   AUCPR: 0.9465
#
# Test Performance by Source:
#   email: F1=0.7537, Accuracy=0.8836 (n=859)
#   mix_email_sms: F1=0.9728, Accuracy=0.9723 (n=1226)
#   sms: F1=0.7279, Accuracy=0.9114 (n=835)
#   youtube: F1=0.8042, Accuracy=0.8082 (n=292)
#
# Training Performance by Source:
#   email: F1=0.7933, Accuracy=0.8633 (n=3322)
#   mix_email_sms: F1=0.9775, Accuracy=0.9774 (n=4912)
#   sms: F1=0.8296, Accuracy=0.8899 (n=2116)
#   youtube: F1=0.7518, Accuracy=0.7695 (n=1653)
#
# Detailed Test Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.95      0.93      0.94      2125
#         Spam       0.87      0.90      0.88      1087
#
#     accuracy                           0.92      3212
#    macro avg       0.91      0.91      0.91      3212
# weighted avg       0.92      0.92      0.92      3212
#
#
# Detailed Training Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.90      0.93      0.92      6872
#         Spam       0.90      0.86      0.88      5131
#
#     accuracy                           0.90     12003
#    macro avg       0.90      0.90      0.90     12003
# weighted avg       0.90      0.90      0.90     12003
#
# Analyzing top 30 most important features...
# Using gain-based importance (preferred for XGBoost)
#
# Top 30 most important features:
#   exclamation_ratio: 979.451050
#   exclamation_count: 771.698975
#   tfidf_our: 676.042236
#   tfidf_your: 654.113159
#   dot_count: 633.735901
#   tfidf_miss out: 593.125977
#   tfidf_i: 564.539062
#   tfidf_amazing: 498.139984
#   tfidf_am: 492.580475
#   tfidf_enron com: 478.909729
#   tfidf_don: 474.623535
#   tfidf_we ve: 412.933838
#   tfidf_get: 379.658783
#   tfidf_all: 373.137848
#   tfidf_i am: 372.145020
#   tfidf_don t: 353.040985
#   tfidf_forwarded by: 344.820374
#   tfidf_now: 331.795441
#   tfidf_ve got: 321.261322
#   avg_word_length: 306.237946
#   tfidf_you: 296.109314
#   upper_ratio: 285.437286
#   tfidf_but wait: 285.213623
#   tfidf_not all: 280.472168
#   tfidf_does anyone: 280.312622
#   tfidf_t: 270.197845
#   tfidf_ect cc: 265.085388
#   tfidf_subject re: 256.527710
#   tfidf_enron: 251.892044
#   tfidf_would: 248.561584
#
# Importance by feature type:
#   tfidf: total=21063.666124, avg=2.106367, count=10000
#   exclamation: total=1751.150024, avg=875.575012, count=2
#   phone: total=481.922408, avg=1.574910, count=306
#   money: total=322.879372, avg=5.472532, count=59
#   upper: total=285.437286, avg=285.437286, count=1
#   source: total=180.911207, avg=12.922229, count=14
#   url: total=177.473637, avg=9.859646, count=18
#   char_count: total=108.005737, avg=108.005737, count=1
#   word_count: total=92.988525, avg=92.988525, count=1
#   email: total=73.180864, avg=2.523478, count=29
#   question: total=8.351110, avg=0.556741, count=15
# Evaluation plots saved to: models/xgboost_10k_bigrams/xgb_evaluation_randomized.png
# Saving XGBoost model and results to: models/xgboost_10k_bigrams
# Saved files:
# - xgb_model_randomized.pkl (trained XGBoost model)
# - xgb_randomized_search.pkl (full randomized search object)
# - feature_importance_randomized.csv (feature importance rankings)
# - xgb_results_summary_randomized.json (comprehensive results)
# - xgb_evaluation_randomized.png (evaluation plots)
#
# ================================================================================
# XGBoost training with AUCPR optimization completed successfully!
# GPU acceleration: Enabled
# Combinations tested: 500
# Best CV AUCPR: 0.9497 (+/- 0.0104)
# Early stopping at iteration: 231
# Optimal threshold: 0.5070
# Test F1 Score (optimal threshold): 0.8807
# Test AUCPR: 0.9465
# Cross-validation used source+label stratification for balanced folds
#
# FAST XGBoost training pipeline completed!
# Key results:
# - Best parameters: {'colsample_bylevel': 0.5320836894770028, 'colsample_bytree': 0.6215201425313747, 'eval_metric': 'aucpr', 'gamma': 0.8350523138957243, 'gpu_id': 0, 'learning_rate': 0.011288034009058942, 'max_delta_step': 1, 'max_depth': 9, 'min_child_weight': 1, 'n_estimators': 173, 'objective': 'binary:logistic', 'random_state': 42, 'reg_alpha': 0.00438149149150876, 'reg_lambda': 0.02131232878302273, 'subsample': 0.7287830312169208, 'tree_method': 'gpu_hist', 'verbosity': 0}
# - Cross-validation F1: 0.9497
# - Test set F1: 0.8807
# - Test set Accuracy: 0.9178
# - GPU acceleration: True
# - Parameter combinations tested: 500

# %% [markdown]
# ## 5. K-Means Clustering
# K-Means is applied as an unsupervised baseline to explore the natural grouping of messages.
#
# The script:
# - Loads engineered features (`X_train.npy`, `X_test.npy`)
# - Trains a K-Means model with a predefined number of clusters
# - Evaluates cluster quality using metrics like Silhouette Score, Adjusted Rand Index (ARI), and Normalized Mutual Information (NMI)
# - Maps clusters to spam/ham classes for comparison with supervised models
# - Generates detailed cluster composition and visualization plots

# %% [markdown]
# ### 5.1. CLUSTERING CONFIGURATION
# Modify these parameters to experiment with different clustering approaches:

# %%
# CLUSTERING CONFIGURATION
# Streamlined configuration for K-Means analysis

CLUSTERING_CONFIG = {
    # Feature Engineering Parameters
    "max_tfidf_features": 500,       # Default TF-IDF features
    "source_weight": 0.0,            # Default source weight
    
    # Clustering Parameters - K values to test (2-8)
    "k_values": list(range(2, 9)),   # Test k from 2 to 8
    
    # Paths
    "data_path": "final_dataset",
    "features_base_dir": "preprocessed/kmeans",  # Features independent of k
    "models_base_dir": "models/kmeans"           # Models depend on k
}

print("Configuration set:")
for key, value in CLUSTERING_CONFIG.items():
    if key == "k_values":
        print(f"  {key}: {value} (will test all)")
    else:
        print(f"  {key}: {value}")
# Out:
# Configuration set:
#   max_tfidf_features: 500
#   source_weight: 0.0
#   k_values: [2, 3, 4, 5, 6, 7, 8] (will test all)
#   data_path: datasets/preprocessed
#   features_base_dir: preprocessed/kmeans
#   models_base_dir: models/kmeans

# %% [markdown]
# ### 5.2. Comprehensive K-Values Analysis
#
# Test all k values from 2 to 8 with multiple configurations:

# %%
# Streamlined K-Means Analysis (K=2-8)
print("STREAMLINED K-MEANS ANALYSIS")
print("=" * 60)
print("Testing k values from 2 to 8 with selected configurations...")

def test_clustering_config(config_name, max_tfidf=50, source_weight=0.0, k_clusters=3):
    """Test a specific clustering configuration"""
    import time
    start_time = time.time()
    
    print(f"\n{'='*60}")
    print(f"TESTING: {config_name}")
    print(f"TF-IDF Features: {max_tfidf}, Source Weight: {source_weight}, K Clusters: {k_clusters}")
    print(f"{'='*60}")
    
    try:
        # Feature Engineering (independent of k - only run once per config)
        features_dir = f"{CLUSTERING_CONFIG['features_base_dir']}/{config_name}"
        features_path = Path(features_dir)
        
        if not features_path.exists():
            print(f"Creating features for {config_name}...")
            features_path, metadata = engineer_features(
                data_path=CLUSTERING_CONFIG["data_path"],
                output_dir=features_dir,
                max_tfidf_features=max_tfidf,
                source_weight=source_weight
            )
        else:
            print(f"Using existing features: {config_name}")
            # Load existing metadata
            with open(features_path / "feature_metadata.json", "r") as f:
                metadata = json.load(f)
        
        # Clustering (depends on k)
        model_dir = f"{CLUSTERING_CONFIG['models_base_dir']}/k{k_clusters}/{config_name}"
        model, results = train_kmeans(
            features_dir=features_dir,
            output_dir=model_dir,
            k_clusters=k_clusters
        )
        
        # Extract key metrics
        perf = results['clustering_performance']
        clusters = results['cluster_analysis']['cluster_composition']
        
        print(f"\nRESULTS SUMMARY:")
        print(f"  Silhouette Score: {perf['silhouette_score']['test']:.3f}")
        print(f"  Rand Index: {perf['adjusted_rand_index']['test']:.3f}")
        print(f"  Mutual Information: {perf['normalized_mutual_info']['test']:.3f}")
        print(f"  Total Features: {metadata['n_features']}")
        
        print(f"\nCluster Composition:")
        for i, cluster in enumerate(clusters):
            spam_rate = cluster['spam_rate'] * 100
            size = cluster['size']
            dominant = cluster['dominant_source']
            print(f"  Cluster {i}: {size:4d} samples, {spam_rate:5.1f}% spam, mainly {dominant}")
        
        # Calculate and display runtime
        end_time = time.time()
        runtime = end_time - start_time
        print(f"\nRuntime: {runtime:.2f} seconds")
        
        return {
            'config': config_name,
            'k': k_clusters,
            'silhouette': perf['silhouette_score']['test'],
            'ari': perf['adjusted_rand_index']['test'],
            'nmi': perf['normalized_mutual_info']['test'],
            'features': metadata['n_features'],
            'clusters': clusters,
            'runtime': runtime
        }
        
    except Exception as e:
        end_time = time.time()
        runtime = end_time - start_time
        print(f"ERROR: {e}")
        print(f"Runtime before error: {runtime:.2f} seconds")
        return None

# Define streamlined test configurations
test_configs = [
    # Current configuration
    {"name": "current", "max_tfidf": 500, "source_weight": 0.0},
    
    # TF-IDF experiments (with source_weight = 0.0)
    {"name": "tfidf_50", "max_tfidf": 50, "source_weight": 0.0},
    {"name": "tfidf_100", "max_tfidf": 100, "source_weight": 0.0},
    {"name": "tfidf_1000", "max_tfidf": 1000, "source_weight": 0.0},
    
    # Source weight experiments (with max_tfidf = 500)
    {"name": "source_0.1", "max_tfidf": 500, "source_weight": 0.1},
    {"name": "source_0.3", "max_tfidf": 500, "source_weight": 0.3},
    {"name": "source_0.5", "max_tfidf": 500, "source_weight": 0.5}
]

all_results = []

for k in CLUSTERING_CONFIG["k_values"]:
    print(f"\nTesting K = {k}")
    print("-" * 40)
    
    k_results = []
    for config in test_configs:
        result = test_clustering_config(
            config["name"],
            max_tfidf=config["max_tfidf"],
            source_weight=config["source_weight"],
            k_clusters=k
        )
        if result:
            k_results.append(result)
            all_results.append(result)
    
    print(f"Completed K = {k}: {len(k_results)} configurations")

print(f"\nTotal completed: {len(all_results)} configurations across all k values")
# Out:
# STREAMLINED K-MEANS ANALYSIS
# ============================================================
# Testing k values from 2 to 8 with selected configurations...
#
# Testing K = 2
# ----------------------------------------
#
# ============================================================
# TESTING: current
# TF-IDF Features: 500, Source Weight: 0.0, K Clusters: 2
# ============================================================
# Using existing features: current
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\current
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=2...
# Model trained. Inertia: 6446996
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.166, Test: 0.161
#   Adjusted Rand Index - Train: -0.007, Test: -0.045
#   Normalized Mutual Info - Train: 0.050, Test: 0.046
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.579
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 505, spam_rate=11.3%, dominant=email
#   Cluster 1: size=2707, spam_rate=38.0%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\current\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\current\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\current\cluster_mapping.pkl
#   - Results: models\kmeans\k2\current\clustering_results.json
#   - Cluster table: models\kmeans\k2\current\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.161
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/current
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.161
#   Rand Index: -0.045
#   Mutual Information: 0.046
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  505 samples,  11.3% spam, mainly email
#   Cluster 1: 2707 samples,  38.0% spam, mainly mix_email_sms
#
# Runtime: 9.25 seconds
#
# ============================================================
# TESTING: tfidf_50
# TF-IDF Features: 50, Source Weight: 0.0, K Clusters: 2
# ============================================================
# Using existing features: tfidf_50
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_50
# Training features: (12003, 107)
# Test features: (3212, 107)
# Training K-Means with k=2...
# Model trained. Inertia: 1110550
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.306, Test: 0.322
#   Adjusted Rand Index - Train: -0.012, Test: -0.030
#   Normalized Mutual Info - Train: 0.016, Test: 0.014
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.532
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2939, spam_rate=35.4%, dominant=mix_email_sms
#   Cluster 1: size= 273, spam_rate=16.8%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\tfidf_50\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\tfidf_50\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\tfidf_50\cluster_mapping.pkl
#   - Results: models\kmeans\k2\tfidf_50\clustering_results.json
#   - Cluster table: models\kmeans\k2\tfidf_50\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.322
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/tfidf_50
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.322
#   Rand Index: -0.030
#   Mutual Information: 0.014
#   Total Features: 107
#
# Cluster Composition:
#   Cluster 0: 2939 samples,  35.4% spam, mainly mix_email_sms
#   Cluster 1:  273 samples,  16.8% spam, mainly email
#
# Runtime: 4.55 seconds
#
# ============================================================
# TESTING: tfidf_100
# TF-IDF Features: 100, Source Weight: 0.0, K Clusters: 2
# ============================================================
# Using existing features: tfidf_100
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_100
# Training features: (12003, 157)
# Test features: (3212, 157)
# Training K-Means with k=2...
# Model trained. Inertia: 1697176
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.225, Test: 0.231
#   Adjusted Rand Index - Train: -0.011, Test: -0.039
#   Normalized Mutual Info - Train: 0.025, Test: 0.025
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.554
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2787, spam_rate=36.6%, dominant=mix_email_sms
#   Cluster 1: size= 425, spam_rate=15.5%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\tfidf_100\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\tfidf_100\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\tfidf_100\cluster_mapping.pkl
#   - Results: models\kmeans\k2\tfidf_100\clustering_results.json
#   - Cluster table: models\kmeans\k2\tfidf_100\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.231
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/tfidf_100
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.231
#   Rand Index: -0.039
#   Mutual Information: 0.025
#   Total Features: 157
#
# Cluster Composition:
#   Cluster 0: 2787 samples,  36.6% spam, mainly mix_email_sms
#   Cluster 1:  425 samples,  15.5% spam, mainly email
#
# Runtime: 4.50 seconds
#
# ============================================================
# TESTING: tfidf_1000
# TF-IDF Features: 1000, Source Weight: 0.0, K Clusters: 2
# ============================================================
# Using existing features: tfidf_1000
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_1000
# Training features: (12003, 1057)
# Test features: (3212, 1057)
# Training K-Means with k=2...
# Model trained. Inertia: 12409712
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.178, Test: 0.166
#   Adjusted Rand Index - Train: -0.006, Test: -0.047
#   Normalized Mutual Info - Train: 0.056, Test: 0.055
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.584
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 494, spam_rate=9.3%, dominant=email
#   Cluster 1: size=2718, spam_rate=38.3%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\tfidf_1000\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\tfidf_1000\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\tfidf_1000\cluster_mapping.pkl
#   - Results: models\kmeans\k2\tfidf_1000\clustering_results.json
#   - Cluster table: models\kmeans\k2\tfidf_1000\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.166
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/tfidf_1000
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.166
#   Rand Index: -0.047
#   Mutual Information: 0.055
#   Total Features: 1057
#
# Cluster Composition:
#   Cluster 0:  494 samples,   9.3% spam, mainly email
#   Cluster 1: 2718 samples,  38.3% spam, mainly mix_email_sms
#
# Runtime: 7.47 seconds
#
# ============================================================
# TESTING: source_0.1
# TF-IDF Features: 500, Source Weight: 0.1, K Clusters: 2
# ============================================================
# Using existing features: source_0.1
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.1
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=2...
# Model trained. Inertia: 6486518
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.153, Test: 0.153
#   Adjusted Rand Index - Train: -0.003, Test: -0.042
#   Normalized Mutual Info - Train: 0.044, Test: 0.045
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.585
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 578, spam_rate=12.6%, dominant=email
#   Cluster 1: size=2634, spam_rate=38.5%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\source_0.1\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\source_0.1\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\source_0.1\cluster_mapping.pkl
#   - Results: models\kmeans\k2\source_0.1\clustering_results.json
#   - Cluster table: models\kmeans\k2\source_0.1\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.153
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/source_0.1
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.153
#   Rand Index: -0.042
#   Mutual Information: 0.045
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  578 samples,  12.6% spam, mainly email
#   Cluster 1: 2634 samples,  38.5% spam, mainly mix_email_sms
#
# Runtime: 6.26 seconds
#
# ============================================================
# TESTING: source_0.3
# TF-IDF Features: 500, Source Weight: 0.3, K Clusters: 2
# ============================================================
# Using existing features: source_0.3
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.3
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=2...
# Model trained. Inertia: 6486518
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.153, Test: 0.153
#   Adjusted Rand Index - Train: -0.003, Test: -0.042
#   Normalized Mutual Info - Train: 0.044, Test: 0.045
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.585
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 578, spam_rate=12.6%, dominant=email
#   Cluster 1: size=2634, spam_rate=38.5%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\source_0.3\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\source_0.3\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\source_0.3\cluster_mapping.pkl
#   - Results: models\kmeans\k2\source_0.3\clustering_results.json
#   - Cluster table: models\kmeans\k2\source_0.3\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.153
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/source_0.3
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.153
#   Rand Index: -0.042
#   Mutual Information: 0.045
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  578 samples,  12.6% spam, mainly email
#   Cluster 1: 2634 samples,  38.5% spam, mainly mix_email_sms
#
# Runtime: 5.77 seconds
#
# ============================================================
# TESTING: source_0.5
# TF-IDF Features: 500, Source Weight: 0.5, K Clusters: 2
# ============================================================
# Using existing features: source_0.5
# Starting K-Means training with k=2
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.5
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=2...
# Model trained. Inertia: 6486518
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.153, Test: 0.153
#   Adjusted Rand Index - Train: -0.003, Test: -0.042
#   Normalized Mutual Info - Train: 0.044, Test: 0.045
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.585
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 578, spam_rate=12.6%, dominant=email
#   Cluster 1: size=2634, spam_rate=38.5%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k2\source_0.5\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k2\source_0.5\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k2\source_0.5\cluster_mapping.pkl
#   - Results: models\kmeans\k2\source_0.5\clustering_results.json
#   - Cluster table: models\kmeans\k2\source_0.5\cluster_summary.csv
# ============================================================
# K-Means training completed (k=2)
# Silhouette score: 0.153
# Classification F1: 0.000
# Results saved to: models/kmeans/k2/source_0.5
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.153
#   Rand Index: -0.042
#   Mutual Information: 0.045
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  578 samples,  12.6% spam, mainly email
#   Cluster 1: 2634 samples,  38.5% spam, mainly mix_email_sms
#
# Runtime: 5.67 seconds
# Completed K = 2: 7 configurations
#
# Testing K = 3
# ----------------------------------------
#
# ============================================================
# TESTING: current
# TF-IDF Features: 500, Source Weight: 0.0, K Clusters: 3
# ============================================================
# Using existing features: current
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\current
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=3...
# Model trained. Inertia: 6360038
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.014, Test: 0.011
#   Adjusted Rand Index - Train: 0.180, Test: 0.270
#   Normalized Mutual Info - Train: 0.255, Test: 0.308
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.835
#   Precision: 0.996
#   Recall: 0.514
#   F1-Score: 0.678
#   ROC-AUC: 0.782
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 473, spam_rate=10.6%, dominant=email
#   Cluster 1: size= 561, spam_rate=99.6%, dominant=mix_email_sms
#   Cluster 2: size=2178, spam_rate=21.9%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\current\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\current\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\current\cluster_mapping.pkl
#   - Results: models\kmeans\k3\current\clustering_results.json
#   - Cluster table: models\kmeans\k3\current\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.011
# Classification F1: 0.678
# Results saved to: models/kmeans/k3/current
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.011
#   Rand Index: 0.270
#   Mutual Information: 0.308
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  473 samples,  10.6% spam, mainly email
#   Cluster 1:  561 samples,  99.6% spam, mainly mix_email_sms
#   Cluster 2: 2178 samples,  21.9% spam, mainly sms
#
# Runtime: 6.32 seconds
#
# ============================================================
# TESTING: tfidf_50
# TF-IDF Features: 50, Source Weight: 0.0, K Clusters: 3
# ============================================================
# Using existing features: tfidf_50
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_50
# Training features: (12003, 107)
# Test features: (3212, 107)
# Training K-Means with k=3...
# Model trained. Inertia: 1061119
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.234, Test: 0.254
#   Adjusted Rand Index - Train: -0.011, Test: -0.038
#   Normalized Mutual Info - Train: 0.024, Test: 0.023
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.551
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2805, spam_rate=36.4%, dominant=mix_email_sms
#   Cluster 1: size=   2, spam_rate=50.0%, dominant=email
#   Cluster 2: size= 405, spam_rate=15.8%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\tfidf_50\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\tfidf_50\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\tfidf_50\cluster_mapping.pkl
#   - Results: models\kmeans\k3\tfidf_50\clustering_results.json
#   - Cluster table: models\kmeans\k3\tfidf_50\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.254
# Classification F1: 0.000
# Results saved to: models/kmeans/k3/tfidf_50
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.254
#   Rand Index: -0.038
#   Mutual Information: 0.023
#   Total Features: 107
#
# Cluster Composition:
#   Cluster 0: 2805 samples,  36.4% spam, mainly mix_email_sms
#   Cluster 1:    2 samples,  50.0% spam, mainly email
#   Cluster 2:  405 samples,  15.8% spam, mainly email
#
# Runtime: 4.27 seconds
#
# ============================================================
# TESTING: tfidf_100
# TF-IDF Features: 100, Source Weight: 0.0, K Clusters: 3
# ============================================================
# Using existing features: tfidf_100
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_100
# Training features: (12003, 157)
# Test features: (3212, 157)
# Training K-Means with k=3...
# Model trained. Inertia: 1644918
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.196, Test: 0.208
#   Adjusted Rand Index - Train: -0.009, Test: -0.040
#   Normalized Mutual Info - Train: 0.029, Test: 0.030
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.662
#   Precision: 0.000
#   Recall: 0.000
#   F1-Score: 0.000
#   ROC-AUC: 0.565
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 498, spam_rate=15.1%, dominant=email
#   Cluster 1: size=2712, spam_rate=37.3%, dominant=mix_email_sms
#   Cluster 2: size=   2, spam_rate=50.0%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\tfidf_100\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\tfidf_100\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\tfidf_100\cluster_mapping.pkl
#   - Results: models\kmeans\k3\tfidf_100\clustering_results.json
#   - Cluster table: models\kmeans\k3\tfidf_100\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.208
# Classification F1: 0.000
# Results saved to: models/kmeans/k3/tfidf_100
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.208
#   Rand Index: -0.040
#   Mutual Information: 0.030
#   Total Features: 157
#
# Cluster Composition:
#   Cluster 0:  498 samples,  15.1% spam, mainly email
#   Cluster 1: 2712 samples,  37.3% spam, mainly mix_email_sms
#   Cluster 2:    2 samples,  50.0% spam, mainly email
#
# Runtime: 4.60 seconds
#
# ============================================================
# TESTING: tfidf_1000
# TF-IDF Features: 1000, Source Weight: 0.0, K Clusters: 3
# ============================================================
# Using existing features: tfidf_1000
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_1000
# Training features: (12003, 1057)
# Test features: (3212, 1057)
# Training K-Means with k=3...
# Model trained. Inertia: 12304261
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: -0.008, Test: -0.014
#   Adjusted Rand Index - Train: 0.180, Test: 0.273
#   Normalized Mutual Info - Train: 0.259, Test: 0.317
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.838
#   Precision: 0.998
#   Recall: 0.523
#   F1-Score: 0.687
#   ROC-AUC: 0.790
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2161, spam_rate=21.9%, dominant=sms
#   Cluster 1: size= 570, spam_rate=99.8%, dominant=mix_email_sms
#   Cluster 2: size= 481, spam_rate=9.4%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\tfidf_1000\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\tfidf_1000\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\tfidf_1000\cluster_mapping.pkl
#   - Results: models\kmeans\k3\tfidf_1000\clustering_results.json
#   - Cluster table: models\kmeans\k3\tfidf_1000\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: -0.014
# Classification F1: 0.687
# Results saved to: models/kmeans/k3/tfidf_1000
#
# RESULTS SUMMARY:
#   Silhouette Score: -0.014
#   Rand Index: 0.273
#   Mutual Information: 0.317
#   Total Features: 1057
#
# Cluster Composition:
#   Cluster 0: 2161 samples,  21.9% spam, mainly sms
#   Cluster 1:  570 samples,  99.8% spam, mainly mix_email_sms
#   Cluster 2:  481 samples,   9.4% spam, mainly email
#
# Runtime: 8.97 seconds
#
# ============================================================
# TESTING: source_0.1
# TF-IDF Features: 500, Source Weight: 0.1, K Clusters: 3
# ============================================================
# Using existing features: source_0.1
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.1
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=3...
# Model trained. Inertia: 6395181
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.013, Test: 0.012
#   Adjusted Rand Index - Train: 0.184, Test: 0.271
#   Normalized Mutual Info - Train: 0.249, Test: 0.307
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.838
#   Precision: 0.998
#   Recall: 0.523
#   F1-Score: 0.687
#   ROC-AUC: 0.783
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 570, spam_rate=99.8%, dominant=mix_email_sms
#   Cluster 1: size=2095, spam_rate=21.4%, dominant=sms
#   Cluster 2: size= 547, spam_rate=12.8%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\source_0.1\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\source_0.1\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\source_0.1\cluster_mapping.pkl
#   - Results: models\kmeans\k3\source_0.1\clustering_results.json
#   - Cluster table: models\kmeans\k3\source_0.1\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.012
# Classification F1: 0.687
# Results saved to: models/kmeans/k3/source_0.1
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.012
#   Rand Index: 0.271
#   Mutual Information: 0.307
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  570 samples,  99.8% spam, mainly mix_email_sms
#   Cluster 1: 2095 samples,  21.4% spam, mainly sms
#   Cluster 2:  547 samples,  12.8% spam, mainly email
#
# Runtime: 6.68 seconds
#
# ============================================================
# TESTING: source_0.3
# TF-IDF Features: 500, Source Weight: 0.3, K Clusters: 3
# ============================================================
# Using existing features: source_0.3
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.3
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=3...
# Model trained. Inertia: 6395181
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.013, Test: 0.012
#   Adjusted Rand Index - Train: 0.184, Test: 0.271
#   Normalized Mutual Info - Train: 0.249, Test: 0.307
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.838
#   Precision: 0.998
#   Recall: 0.523
#   F1-Score: 0.687
#   ROC-AUC: 0.783
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 570, spam_rate=99.8%, dominant=mix_email_sms
#   Cluster 1: size=2095, spam_rate=21.4%, dominant=sms
#   Cluster 2: size= 547, spam_rate=12.8%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\source_0.3\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\source_0.3\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\source_0.3\cluster_mapping.pkl
#   - Results: models\kmeans\k3\source_0.3\clustering_results.json
#   - Cluster table: models\kmeans\k3\source_0.3\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.012
# Classification F1: 0.687
# Results saved to: models/kmeans/k3/source_0.3
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.012
#   Rand Index: 0.271
#   Mutual Information: 0.307
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  570 samples,  99.8% spam, mainly mix_email_sms
#   Cluster 1: 2095 samples,  21.4% spam, mainly sms
#   Cluster 2:  547 samples,  12.8% spam, mainly email
#
# Runtime: 6.17 seconds
#
# ============================================================
# TESTING: source_0.5
# TF-IDF Features: 500, Source Weight: 0.5, K Clusters: 3
# ============================================================
# Using existing features: source_0.5
# Starting K-Means training with k=3
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.5
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=3...
# Model trained. Inertia: 6395181
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.013, Test: 0.012
#   Adjusted Rand Index - Train: 0.184, Test: 0.271
#   Normalized Mutual Info - Train: 0.249, Test: 0.307
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.838
#   Precision: 0.998
#   Recall: 0.523
#   F1-Score: 0.687
#   ROC-AUC: 0.783
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 570, spam_rate=99.8%, dominant=mix_email_sms
#   Cluster 1: size=2095, spam_rate=21.4%, dominant=sms
#   Cluster 2: size= 547, spam_rate=12.8%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k3\source_0.5\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k3\source_0.5\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k3\source_0.5\cluster_mapping.pkl
#   - Results: models\kmeans\k3\source_0.5\clustering_results.json
#   - Cluster table: models\kmeans\k3\source_0.5\cluster_summary.csv
# ============================================================
# K-Means training completed (k=3)
# Silhouette score: 0.012
# Classification F1: 0.687
# Results saved to: models/kmeans/k3/source_0.5
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.012
#   Rand Index: 0.271
#   Mutual Information: 0.307
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  570 samples,  99.8% spam, mainly mix_email_sms
#   Cluster 1: 2095 samples,  21.4% spam, mainly sms
#   Cluster 2:  547 samples,  12.8% spam, mainly email
#
# Runtime: 6.16 seconds
# Completed K = 3: 7 configurations
#
# Testing K = 4
# ----------------------------------------
#
# ============================================================
# TESTING: current
# TF-IDF Features: 500, Source Weight: 0.0, K Clusters: 4
# ============================================================
# Using existing features: current
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\current
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=4...
# Model trained. Inertia: 6304730
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.015, Test: 0.013
#   Adjusted Rand Index - Train: 0.175, Test: 0.252
#   Normalized Mutual Info - Train: 0.241, Test: 0.290
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.835
#   Precision: 0.996
#   Recall: 0.513
#   F1-Score: 0.678
#   ROC-AUC: 0.789
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2063, spam_rate=22.1%, dominant=sms
#   Cluster 1: size= 540, spam_rate=10.4%, dominant=email
#   Cluster 2: size=  49, spam_rate=34.7%, dominant=email
#   Cluster 3: size= 560, spam_rate=99.6%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\current\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\current\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\current\cluster_mapping.pkl
#   - Results: models\kmeans\k4\current\clustering_results.json
#   - Cluster table: models\kmeans\k4\current\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.013
# Classification F1: 0.678
# Results saved to: models/kmeans/k4/current
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.013
#   Rand Index: 0.252
#   Mutual Information: 0.290
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0: 2063 samples,  22.1% spam, mainly sms
#   Cluster 1:  540 samples,  10.4% spam, mainly email
#   Cluster 2:   49 samples,  34.7% spam, mainly email
#   Cluster 3:  560 samples,  99.6% spam, mainly mix_email_sms
#
# Runtime: 8.31 seconds
#
# ============================================================
# TESTING: tfidf_50
# TF-IDF Features: 50, Source Weight: 0.0, K Clusters: 4
# ============================================================
# Using existing features: tfidf_50
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_50
# Training features: (12003, 107)
# Test features: (3212, 107)
# Training K-Means with k=4...
# Model trained. Inertia: 1023560
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.104, Test: 0.126
#   Adjusted Rand Index - Train: 0.134, Test: 0.210
#   Normalized Mutual Info - Train: 0.191, Test: 0.229
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.793
#   Precision: 0.984
#   Recall: 0.394
#   F1-Score: 0.562
#   ROC-AUC: 0.713
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2416, spam_rate=24.9%, dominant=sms
#   Cluster 1: size= 359, spam_rate=15.6%, dominant=email
#   Cluster 2: size=   2, spam_rate=50.0%, dominant=email
#   Cluster 3: size= 435, spam_rate=98.4%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\tfidf_50\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\tfidf_50\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\tfidf_50\cluster_mapping.pkl
#   - Results: models\kmeans\k4\tfidf_50\clustering_results.json
#   - Cluster table: models\kmeans\k4\tfidf_50\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.126
# Classification F1: 0.562
# Results saved to: models/kmeans/k4/tfidf_50
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.126
#   Rand Index: 0.210
#   Mutual Information: 0.229
#   Total Features: 107
#
# Cluster Composition:
#   Cluster 0: 2416 samples,  24.9% spam, mainly sms
#   Cluster 1:  359 samples,  15.6% spam, mainly email
#   Cluster 2:    2 samples,  50.0% spam, mainly email
#   Cluster 3:  435 samples,  98.4% spam, mainly mix_email_sms
#
# Runtime: 5.44 seconds
#
# ============================================================
# TESTING: tfidf_100
# TF-IDF Features: 100, Source Weight: 0.0, K Clusters: 4
# ============================================================
# Using existing features: tfidf_100
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_100
# Training features: (12003, 157)
# Test features: (3212, 157)
# Training K-Means with k=4...
# Model trained. Inertia: 1598718
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.064, Test: 0.074
#   Adjusted Rand Index - Train: 0.185, Test: 0.270
#   Normalized Mutual Info - Train: 0.230, Test: 0.281
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.828
#   Precision: 0.985
#   Recall: 0.500
#   F1-Score: 0.663
#   ROC-AUC: 0.763
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2192, spam_rate=21.6%, dominant=sms
#   Cluster 1: size=   2, spam_rate=50.0%, dominant=email
#   Cluster 2: size= 551, spam_rate=98.5%, dominant=mix_email_sms
#   Cluster 3: size= 467, spam_rate=15.0%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\tfidf_100\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\tfidf_100\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\tfidf_100\cluster_mapping.pkl
#   - Results: models\kmeans\k4\tfidf_100\clustering_results.json
#   - Cluster table: models\kmeans\k4\tfidf_100\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.074
# Classification F1: 0.663
# Results saved to: models/kmeans/k4/tfidf_100
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.074
#   Rand Index: 0.270
#   Mutual Information: 0.281
#   Total Features: 157
#
# Cluster Composition:
#   Cluster 0: 2192 samples,  21.6% spam, mainly sms
#   Cluster 1:    2 samples,  50.0% spam, mainly email
#   Cluster 2:  551 samples,  98.5% spam, mainly mix_email_sms
#   Cluster 3:  467 samples,  15.0% spam, mainly email
#
# Runtime: 4.77 seconds
#
# ============================================================
# TESTING: tfidf_1000
# TF-IDF Features: 1000, Source Weight: 0.0, K Clusters: 4
# ============================================================
# Using existing features: tfidf_1000
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_1000
# Training features: (12003, 1057)
# Test features: (3212, 1057)
# Training K-Means with k=4...
# Model trained. Inertia: 12240422
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: -0.007, Test: -0.013
#   Adjusted Rand Index - Train: 0.185, Test: 0.266
#   Normalized Mutual Info - Train: 0.289, Test: 0.326
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.837
#   Precision: 0.998
#   Recall: 0.521
#   F1-Score: 0.684
#   ROC-AUC: 0.820
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 125, spam_rate=47.2%, dominant=email
#   Cluster 1: size= 567, spam_rate=99.8%, dominant=mix_email_sms
#   Cluster 2: size= 411, spam_rate=0.5%, dominant=email
#   Cluster 3: size=2109, spam_rate=21.8%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\tfidf_1000\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\tfidf_1000\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\tfidf_1000\cluster_mapping.pkl
#   - Results: models\kmeans\k4\tfidf_1000\clustering_results.json
#   - Cluster table: models\kmeans\k4\tfidf_1000\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: -0.013
# Classification F1: 0.684
# Results saved to: models/kmeans/k4/tfidf_1000
#
# RESULTS SUMMARY:
#   Silhouette Score: -0.013
#   Rand Index: 0.266
#   Mutual Information: 0.326
#   Total Features: 1057
#
# Cluster Composition:
#   Cluster 0:  125 samples,  47.2% spam, mainly email
#   Cluster 1:  567 samples,  99.8% spam, mainly mix_email_sms
#   Cluster 2:  411 samples,   0.5% spam, mainly email
#   Cluster 3: 2109 samples,  21.8% spam, mainly sms
#
# Runtime: 10.81 seconds
#
# ============================================================
# TESTING: source_0.1
# TF-IDF Features: 500, Source Weight: 0.1, K Clusters: 4
# ============================================================
# Using existing features: source_0.1
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.1
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=4...
# Model trained. Inertia: 6349229
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.005, Test: 0.006
#   Adjusted Rand Index - Train: 0.160, Test: 0.165
#   Normalized Mutual Info - Train: 0.291, Test: 0.299
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.841
#   Precision: 0.997
#   Recall: 0.532
#   F1-Score: 0.693
#   ROC-AUC: 0.859
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 580, spam_rate=99.7%, dominant=mix_email_sms
#   Cluster 1: size= 586, spam_rate=0.5%, dominant=mix_email_sms
#   Cluster 2: size= 521, spam_rate=11.3%, dominant=email
#   Cluster 3: size=1525, spam_rate=29.3%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\source_0.1\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\source_0.1\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\source_0.1\cluster_mapping.pkl
#   - Results: models\kmeans\k4\source_0.1\clustering_results.json
#   - Cluster table: models\kmeans\k4\source_0.1\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.006
# Classification F1: 0.693
# Results saved to: models/kmeans/k4/source_0.1
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.006
#   Rand Index: 0.165
#   Mutual Information: 0.299
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  580 samples,  99.7% spam, mainly mix_email_sms
#   Cluster 1:  586 samples,   0.5% spam, mainly mix_email_sms
#   Cluster 2:  521 samples,  11.3% spam, mainly email
#   Cluster 3: 1525 samples,  29.3% spam, mainly sms
#
# Runtime: 8.76 seconds
#
# ============================================================
# TESTING: source_0.3
# TF-IDF Features: 500, Source Weight: 0.3, K Clusters: 4
# ============================================================
# Using existing features: source_0.3
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.3
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=4...
# Model trained. Inertia: 6349229
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.005, Test: 0.006
#   Adjusted Rand Index - Train: 0.160, Test: 0.165
#   Normalized Mutual Info - Train: 0.291, Test: 0.299
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.841
#   Precision: 0.997
#   Recall: 0.532
#   F1-Score: 0.693
#   ROC-AUC: 0.859
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 580, spam_rate=99.7%, dominant=mix_email_sms
#   Cluster 1: size= 586, spam_rate=0.5%, dominant=mix_email_sms
#   Cluster 2: size= 521, spam_rate=11.3%, dominant=email
#   Cluster 3: size=1525, spam_rate=29.3%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\source_0.3\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\source_0.3\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\source_0.3\cluster_mapping.pkl
#   - Results: models\kmeans\k4\source_0.3\clustering_results.json
#   - Cluster table: models\kmeans\k4\source_0.3\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.006
# Classification F1: 0.693
# Results saved to: models/kmeans/k4/source_0.3
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.006
#   Rand Index: 0.165
#   Mutual Information: 0.299
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  580 samples,  99.7% spam, mainly mix_email_sms
#   Cluster 1:  586 samples,   0.5% spam, mainly mix_email_sms
#   Cluster 2:  521 samples,  11.3% spam, mainly email
#   Cluster 3: 1525 samples,  29.3% spam, mainly sms
#
# Runtime: 8.62 seconds
#
# ============================================================
# TESTING: source_0.5
# TF-IDF Features: 500, Source Weight: 0.5, K Clusters: 4
# ============================================================
# Using existing features: source_0.5
# Starting K-Means training with k=4
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.5
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=4...
# Model trained. Inertia: 6349229
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.005, Test: 0.006
#   Adjusted Rand Index - Train: 0.160, Test: 0.165
#   Normalized Mutual Info - Train: 0.291, Test: 0.299
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.841
#   Precision: 0.997
#   Recall: 0.532
#   F1-Score: 0.693
#   ROC-AUC: 0.859
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 580, spam_rate=99.7%, dominant=mix_email_sms
#   Cluster 1: size= 586, spam_rate=0.5%, dominant=mix_email_sms
#   Cluster 2: size= 521, spam_rate=11.3%, dominant=email
#   Cluster 3: size=1525, spam_rate=29.3%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k4\source_0.5\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k4\source_0.5\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k4\source_0.5\cluster_mapping.pkl
#   - Results: models\kmeans\k4\source_0.5\clustering_results.json
#   - Cluster table: models\kmeans\k4\source_0.5\cluster_summary.csv
# ============================================================
# K-Means training completed (k=4)
# Silhouette score: 0.006
# Classification F1: 0.693
# Results saved to: models/kmeans/k4/source_0.5
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.006
#   Rand Index: 0.165
#   Mutual Information: 0.299
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  580 samples,  99.7% spam, mainly mix_email_sms
#   Cluster 1:  586 samples,   0.5% spam, mainly mix_email_sms
#   Cluster 2:  521 samples,  11.3% spam, mainly email
#   Cluster 3: 1525 samples,  29.3% spam, mainly sms
#
# Runtime: 8.02 seconds
# Completed K = 4: 7 configurations
#
# Testing K = 5
# ----------------------------------------
#
# ============================================================
# TESTING: current
# TF-IDF Features: 500, Source Weight: 0.0, K Clusters: 5
# ============================================================
# Using existing features: current
# Starting K-Means training with k=5
# ============================================================
# Loading features from: preprocessed\kmeans\current
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=5...
# Model trained. Inertia: 6272736
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: -0.032, Test: -0.038
#   Adjusted Rand Index - Train: 0.231, Test: 0.311
#   Normalized Mutual Info - Train: 0.253, Test: 0.301
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.856
#   Precision: 0.860
#   Recall: 0.685
#   F1-Score: 0.763
#   ROC-AUC: 0.838
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 502, spam_rate=10.8%, dominant=email
#   Cluster 1: size= 318, spam_rate=62.6%, dominant=sms
#   Cluster 2: size= 548, spam_rate=99.6%, dominant=mix_email_sms
#   Cluster 3: size=1842, spam_rate=15.6%, dominant=sms
#   Cluster 4: size=   2, spam_rate=50.0%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k5\current\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k5\current\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k5\current\cluster_mapping.pkl
#   - Results: models\kmeans\k5\current\clustering_results.json
#   - Cluster table: models\kmeans\k5\current\cluster_summary.csv
# ============================================================
# K-Means training completed (k=5)
# Silhouette score: -0.038
# Classification F1: 0.763
# Results saved to: models/kmeans/k5/current
#
# RESULTS SUMMARY:
#   Silhouette Score: -0.038
#   Rand Index: 0.311
#   Mutual Information: 0.301
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  502 samples,  10.8% spam, mainly email
#   Cluster 1:  318 samples,  62.6% spam, mainly sms
#   Cluster 2:  548 samples,  99.6% spam, mainly mix_email_sms
#   Cluster 3: 1842 samples,  15.6% spam, mainly sms
#   Cluster 4:    2 samples,  50.0% spam, mainly email
#
# Runtime: 7.24 seconds
#
# ============================================================
# TESTING: tfidf_50
# TF-IDF Features: 50, Source Weight: 0.0, K Clusters: 5
# ============================================================
# Using existing features: tfidf_50
# Starting K-Means training with k=5
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_50
# Training features: (12003, 107)
# Test features: (3212, 107)
# Training K-Means with k=5...
# Model trained. Inertia: 998639
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.079, Test: 0.088
#   Adjusted Rand Index - Train: 0.153, Test: 0.230
#   Normalized Mutual Info - Train: 0.171, Test: 0.205
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.797
#   Precision: 0.793
#   Recall: 0.542
#   F1-Score: 0.644
#   ROC-AUC: 0.757
# Analyzing cluster composition (Test)...
#   Cluster 0: size=2103, spam_rate=21.0%, dominant=mix_email_sms
#   Cluster 1: size= 349, spam_rate=57.6%, dominant=sms
#   Cluster 2: size= 364, spam_rate=15.1%, dominant=email
#   Cluster 3: size=   2, spam_rate=50.0%, dominant=email
#   Cluster 4: size= 394, spam_rate=98.5%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k5\tfidf_50\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k5\tfidf_50\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k5\tfidf_50\cluster_mapping.pkl
#   - Results: models\kmeans\k5\tfidf_50\clustering_results.json
#   - Cluster table: models\kmeans\k5\tfidf_50\cluster_summary.csv
# ============================================================
# K-Means training completed (k=5)
# Silhouette score: 0.088
# Classification F1: 0.644
# Results saved to: models/kmeans/k5/tfidf_50
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.088
#   Rand Index: 0.230
#   Mutual Information: 0.205
#   Total Features: 107
#
# Cluster Composition:
#   Cluster 0: 2103 samples,  21.0% spam, mainly mix_email_sms
#   Cluster 1:  349 samples,  57.6% spam, mainly sms
#   Cluster 2:  364 samples,  15.1% spam, mainly email
#   Cluster 3:    2 samples,  50.0% spam, mainly email
#   Cluster 4:  394 samples,  98.5% spam, mainly mix_email_sms
#
# Runtime: 5.64 seconds
#
# ============================================================
# TESTING: tfidf_100
# TF-IDF Features: 100, Source Weight: 0.0, K Clusters: 5
# ============================================================
# Using existing features: tfidf_100
# Starting K-Means training with k=5
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_100
# Training features: (12003, 157)
# Test features: (3212, 157)
# Training K-Means with k=5...
# Model trained. Inertia: 1572986
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.031, Test: 0.040
#   Adjusted Rand Index - Train: 0.218, Test: 0.295
#   Normalized Mutual Info - Train: 0.223, Test: 0.263
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.835
#   Precision: 0.830
#   Recall: 0.645
#   F1-Score: 0.726
#   ROC-AUC: 0.805
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 460, spam_rate=15.7%, dominant=email
# ...
# Silhouette score: 0.008
# Classification F1: 0.735
# Results saved to: models/kmeans/k8/current
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.008
#   Rand Index: 0.249
#   Mutual Information: 0.284
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  185 samples,  62.7% spam, mainly email
#   Cluster 1:    2 samples,  50.0% spam, mainly email
#   Cluster 2:  416 samples,   0.5% spam, mainly email
#   Cluster 3:  216 samples,  97.7% spam, mainly mix_email_sms
#   Cluster 4:   92 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 5: 2040 samples,  20.0% spam, mainly sms
#   Cluster 6:  196 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 7:   65 samples,  95.4% spam, mainly mix_email_sms
#
# Runtime: 5.84 seconds
#
# ============================================================
# TESTING: tfidf_50
# TF-IDF Features: 50, Source Weight: 0.0, K Clusters: 8
# ============================================================
# Using existing features: tfidf_50
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_50
# Training features: (12003, 107)
# Test features: (3212, 107)
# Training K-Means with k=8...
# Model trained. Inertia: 942747
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.034, Test: 0.043
#   Adjusted Rand Index - Train: 0.133, Test: 0.161
#   Normalized Mutual Info - Train: 0.205, Test: 0.219
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.847
#   Precision: 0.826
#   Recall: 0.695
#   F1-Score: 0.755
#   ROC-AUC: 0.865
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 383, spam_rate=80.9%, dominant=mix_email_sms
#   Cluster 1: size=1269, spam_rate=19.9%, dominant=sms
#   Cluster 2: size=  17, spam_rate=41.2%, dominant=email
#   Cluster 3: size= 249, spam_rate=67.1%, dominant=sms
#   Cluster 4: size= 594, spam_rate=3.0%, dominant=mix_email_sms
#   Cluster 5: size= 282, spam_rate=98.6%, dominant=mix_email_sms
#   Cluster 6: size= 418, spam_rate=13.2%, dominant=email
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\tfidf_50\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\tfidf_50\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\tfidf_50\cluster_mapping.pkl
#   - Results: models\kmeans\k8\tfidf_50\clustering_results.json
#   - Cluster table: models\kmeans\k8\tfidf_50\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: 0.043
# Classification F1: 0.755
# Results saved to: models/kmeans/k8/tfidf_50
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.043
#   Rand Index: 0.161
#   Mutual Information: 0.219
#   Total Features: 107
#
# Cluster Composition:
#   Cluster 0:  383 samples,  80.9% spam, mainly mix_email_sms
#   Cluster 1: 1269 samples,  19.9% spam, mainly sms
#   Cluster 2:   17 samples,  41.2% spam, mainly email
#   Cluster 3:  249 samples,  67.1% spam, mainly sms
#   Cluster 4:  594 samples,   3.0% spam, mainly mix_email_sms
#   Cluster 5:  282 samples,  98.6% spam, mainly mix_email_sms
#   Cluster 6:  418 samples,  13.2% spam, mainly email
#
# Runtime: 3.92 seconds
#
# ============================================================
# TESTING: tfidf_100
# TF-IDF Features: 100, Source Weight: 0.0, K Clusters: 8
# ============================================================
# Using existing features: tfidf_100
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_100
# Training features: (12003, 157)
# Test features: (3212, 157)
# Training K-Means with k=8...
# Model trained. Inertia: 1504413
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.025, Test: 0.031
#   Adjusted Rand Index - Train: 0.116, Test: 0.125
#   Normalized Mutual Info - Train: 0.189, Test: 0.204
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.814
#   Precision: 0.863
#   Recall: 0.534
#   F1-Score: 0.660
#   ROC-AUC: 0.835
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 410, spam_rate=99.0%, dominant=mix_email_sms
#   Cluster 2: size= 421, spam_rate=8.3%, dominant=email
#   Cluster 3: size=1406, spam_rate=28.3%, dominant=sms
#   Cluster 4: size= 263, spam_rate=66.5%, dominant=sms
#   Cluster 5: size=  16, spam_rate=43.8%, dominant=email
#   Cluster 6: size= 619, spam_rate=5.5%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\tfidf_100\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\tfidf_100\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\tfidf_100\cluster_mapping.pkl
#   - Results: models\kmeans\k8\tfidf_100\clustering_results.json
#   - Cluster table: models\kmeans\k8\tfidf_100\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: 0.031
# Classification F1: 0.660
# Results saved to: models/kmeans/k8/tfidf_100
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.031
#   Rand Index: 0.125
#   Mutual Information: 0.204
#   Total Features: 157
#
# Cluster Composition:
#   Cluster 0:  410 samples,  99.0% spam, mainly mix_email_sms
#   Cluster 1:  421 samples,   8.3% spam, mainly email
#   Cluster 2: 1406 samples,  28.3% spam, mainly sms
#   Cluster 3:  263 samples,  66.5% spam, mainly sms
#   Cluster 4:   16 samples,  43.8% spam, mainly email
#   Cluster 5:  619 samples,   5.5% spam, mainly mix_email_sms
#
# Runtime: 4.33 seconds
#
# ============================================================
# TESTING: tfidf_1000
# TF-IDF Features: 1000, Source Weight: 0.0, K Clusters: 8
# ============================================================
# Using existing features: tfidf_1000
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\tfidf_1000
# Training features: (12003, 1057)
# Test features: (3212, 1057)
# Training K-Means with k=8...
# Model trained. Inertia: 12072625
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: -0.013, Test: -0.015
#   Adjusted Rand Index - Train: 0.130, Test: 0.140
#   Normalized Mutual Info - Train: 0.286, Test: 0.292
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.849
#   Precision: 0.939
#   Recall: 0.592
#   F1-Score: 0.726
#   ROC-AUC: 0.887
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 589, spam_rate=0.5%, dominant=mix_email_sms
#   Cluster 1: size= 456, spam_rate=1.3%, dominant=email
#   Cluster 2: size= 268, spam_rate=100.0%, dominant=mix_email_sms
#   Cluster 3: size= 117, spam_rate=73.5%, dominant=email
#   Cluster 4: size= 276, spam_rate=99.6%, dominant=mix_email_sms
#   Cluster 5: size=   5, spam_rate=20.0%, dominant=sms
#   Cluster 6: size=  24, spam_rate=58.3%, dominant=email
#   Cluster 7: size=1477, spam_rate=29.4%, dominant=sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\tfidf_1000\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\tfidf_1000\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\tfidf_1000\cluster_mapping.pkl
#   - Results: models\kmeans\k8\tfidf_1000\clustering_results.json
#   - Cluster table: models\kmeans\k8\tfidf_1000\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: -0.015
# Classification F1: 0.726
# Results saved to: models/kmeans/k8/tfidf_1000
#
# RESULTS SUMMARY:
#   Silhouette Score: -0.015
#   Rand Index: 0.140
#   Mutual Information: 0.292
#   Total Features: 1057
#
# Cluster Composition:
#   Cluster 0:  589 samples,   0.5% spam, mainly mix_email_sms
#   Cluster 1:  456 samples,   1.3% spam, mainly email
#   Cluster 2:  268 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 3:  117 samples,  73.5% spam, mainly email
#   Cluster 4:  276 samples,  99.6% spam, mainly mix_email_sms
#   Cluster 5:    5 samples,  20.0% spam, mainly sms
#   Cluster 6:   24 samples,  58.3% spam, mainly email
#   Cluster 7: 1477 samples,  29.4% spam, mainly sms
#
# Runtime: 8.17 seconds
#
# ============================================================
# TESTING: source_0.1
# TF-IDF Features: 500, Source Weight: 0.1, K Clusters: 8
# ============================================================
# Using existing features: source_0.1
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.1
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=8...
# Model trained. Inertia: 6184342
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.003, Test: 0.003
#   Adjusted Rand Index - Train: 0.115, Test: 0.115
#   Normalized Mutual Info - Train: 0.243, Test: 0.245
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.834
#   Precision: 0.988
#   Recall: 0.516
#   F1-Score: 0.678
#   ROC-AUC: 0.857
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 128, spam_rate=18.8%, dominant=email
#   Cluster 1: size= 582, spam_rate=0.7%, dominant=mix_email_sms
#   Cluster 2: size=  66, spam_rate=95.5%, dominant=mix_email_sms
#   Cluster 3: size=   1, spam_rate=0.0%, dominant=email
#   Cluster 4: size= 539, spam_rate=12.4%, dominant=email
#   Cluster 5: size= 250, spam_rate=100.0%, dominant=mix_email_sms
#   Cluster 6: size=1394, spam_rate=30.9%, dominant=sms
#   Cluster 7: size= 252, spam_rate=98.4%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\source_0.1\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\source_0.1\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\source_0.1\cluster_mapping.pkl
#   - Results: models\kmeans\k8\source_0.1\clustering_results.json
#   - Cluster table: models\kmeans\k8\source_0.1\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: 0.003
# Classification F1: 0.678
# Results saved to: models/kmeans/k8/source_0.1
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.003
#   Rand Index: 0.115
#   Mutual Information: 0.245
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  128 samples,  18.8% spam, mainly email
#   Cluster 1:  582 samples,   0.7% spam, mainly mix_email_sms
#   Cluster 2:   66 samples,  95.5% spam, mainly mix_email_sms
#   Cluster 3:    1 samples,   0.0% spam, mainly email
#   Cluster 4:  539 samples,  12.4% spam, mainly email
#   Cluster 5:  250 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 6: 1394 samples,  30.9% spam, mainly sms
#   Cluster 7:  252 samples,  98.4% spam, mainly mix_email_sms
#
# Runtime: 6.75 seconds
#
# ============================================================
# TESTING: source_0.3
# TF-IDF Features: 500, Source Weight: 0.3, K Clusters: 8
# ============================================================
# Using existing features: source_0.3
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.3
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=8...
# Model trained. Inertia: 6184342
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.003, Test: 0.003
#   Adjusted Rand Index - Train: 0.115, Test: 0.115
#   Normalized Mutual Info - Train: 0.243, Test: 0.245
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.834
#   Precision: 0.988
#   Recall: 0.516
#   F1-Score: 0.678
#   ROC-AUC: 0.857
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 128, spam_rate=18.8%, dominant=email
#   Cluster 1: size= 582, spam_rate=0.7%, dominant=mix_email_sms
#   Cluster 2: size=  66, spam_rate=95.5%, dominant=mix_email_sms
#   Cluster 3: size=   1, spam_rate=0.0%, dominant=email
#   Cluster 4: size= 539, spam_rate=12.4%, dominant=email
#   Cluster 5: size= 250, spam_rate=100.0%, dominant=mix_email_sms
#   Cluster 6: size=1394, spam_rate=30.9%, dominant=sms
#   Cluster 7: size= 252, spam_rate=98.4%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\source_0.3\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\source_0.3\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\source_0.3\cluster_mapping.pkl
#   - Results: models\kmeans\k8\source_0.3\clustering_results.json
#   - Cluster table: models\kmeans\k8\source_0.3\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: 0.003
# Classification F1: 0.678
# Results saved to: models/kmeans/k8/source_0.3
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.003
#   Rand Index: 0.115
#   Mutual Information: 0.245
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  128 samples,  18.8% spam, mainly email
#   Cluster 1:  582 samples,   0.7% spam, mainly mix_email_sms
#   Cluster 2:   66 samples,  95.5% spam, mainly mix_email_sms
#   Cluster 3:    1 samples,   0.0% spam, mainly email
#   Cluster 4:  539 samples,  12.4% spam, mainly email
#   Cluster 5:  250 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 6: 1394 samples,  30.9% spam, mainly sms
#   Cluster 7:  252 samples,  98.4% spam, mainly mix_email_sms
#
# Runtime: 7.94 seconds
#
# ============================================================
# TESTING: source_0.5
# TF-IDF Features: 500, Source Weight: 0.5, K Clusters: 8
# ============================================================
# Using existing features: source_0.5
# Starting K-Means training with k=8
# ============================================================
# Loading features from: preprocessed\kmeans\source_0.5
# Training features: (12003, 557)
# Test features: (3212, 557)
# Training K-Means with k=8...
# Model trained. Inertia: 6184342
# Evaluating clustering performance...
# Clustering Metrics:
#   Silhouette Score - Train: 0.003, Test: 0.003
#   Adjusted Rand Index - Train: 0.115, Test: 0.115
#   Normalized Mutual Info - Train: 0.243, Test: 0.245
# Evaluating classification performance...
# Classification Metrics:
#   Accuracy: 0.834
#   Precision: 0.988
#   Recall: 0.516
#   F1-Score: 0.678
#   ROC-AUC: 0.857
# Analyzing cluster composition (Test)...
#   Cluster 0: size= 128, spam_rate=18.8%, dominant=email
#   Cluster 1: size= 582, spam_rate=0.7%, dominant=mix_email_sms
#   Cluster 2: size=  66, spam_rate=95.5%, dominant=mix_email_sms
#   Cluster 3: size=   1, spam_rate=0.0%, dominant=email
#   Cluster 4: size= 539, spam_rate=12.4%, dominant=email
#   Cluster 5: size= 250, spam_rate=100.0%, dominant=mix_email_sms
#   Cluster 6: size=1394, spam_rate=30.9%, dominant=sms
#   Cluster 7: size= 252, spam_rate=98.4%, dominant=mix_email_sms
# Creating enhanced visualizations with confusion matrix...
# Enhanced visualizations saved to: models\kmeans\k8\source_0.5\clustering_analysis.png
# Results saved:
#   - Model: models\kmeans\k8\source_0.5\kmeans_model.pkl
#   - Cluster mapping: models\kmeans\k8\source_0.5\cluster_mapping.pkl
#   - Results: models\kmeans\k8\source_0.5\clustering_results.json
#   - Cluster table: models\kmeans\k8\source_0.5\cluster_summary.csv
# ============================================================
# K-Means training completed (k=8)
# Silhouette score: 0.003
# Classification F1: 0.678
# Results saved to: models/kmeans/k8/source_0.5
#
# RESULTS SUMMARY:
#   Silhouette Score: 0.003
#   Rand Index: 0.115
#   Mutual Information: 0.245
#   Total Features: 557
#
# Cluster Composition:
#   Cluster 0:  128 samples,  18.8% spam, mainly email
#   Cluster 1:  582 samples,   0.7% spam, mainly mix_email_sms
#   Cluster 2:   66 samples,  95.5% spam, mainly mix_email_sms
#   Cluster 3:    1 samples,   0.0% spam, mainly email
#   Cluster 4:  539 samples,  12.4% spam, mainly email
#   Cluster 5:  250 samples, 100.0% spam, mainly mix_email_sms
#   Cluster 6: 1394 samples,  30.9% spam, mainly sms
#   Cluster 7:  252 samples,  98.4% spam, mainly mix_email_sms
#
# Runtime: 6.90 seconds
# Completed K = 8: 7 configurations
#
# Total completed: 49 configurations across all k values

# %% [markdown]
# ### 5.3. Comprehensive Analysis Summary
#
# Detailed analysis for all tested k values with current configuration:

# %%
# Comprehensive analysis for current configuration across all k values
print("COMPREHENSIVE CLUSTERING ANALYSIS - CURRENT CONFIGURATION")
print("=" * 80)

# Load and display results for each k value
for k in CLUSTERING_CONFIG["k_values"]:
    results_path = Path(f"{CLUSTERING_CONFIG['models_base_dir']}/k{k}/current/clustering_results.json")
    
    if results_path.exists():
        with open(results_path, 'r') as f:
            results = json.load(f)
        
        # Add indicator for chosen configuration
        chosen_indicator = " (chosen one)" if k == 3 else ""
        
        print(f"{'='*80}")
        print(f"K = {k} RESULTS (Current Configuration){chosen_indicator}")
        print(f"{'='*80}")
        
        # Clustering Performance
        clustering_perf = results['clustering_performance']
        print("\nClustering Performance:")
        print(f"  Silhouette Score:       Train={clustering_perf['silhouette_score']['train']:.3f}, Test={clustering_perf['silhouette_score']['test']:.3f}")
        print(f"  Adjusted Rand Index:    Train={clustering_perf['adjusted_rand_index']['train']:.3f}, Test={clustering_perf['adjusted_rand_index']['test']:.3f}")
        print(f"  Normalized Mutual Info: Train={clustering_perf['normalized_mutual_info']['train']:.3f}, Test={clustering_perf['normalized_mutual_info']['test']:.3f}")
        
        # Classification Performance
        class_perf = results['classification_performance']
        print("\nClassification Performance:")
        print(f"  Accuracy:          {class_perf['accuracy']:.3f}")
        print(f"  Precision:         {class_perf['precision']:.3f}")
        print(f"  Recall:            {class_perf['recall']:.3f}")
        print(f"  F1-Score:          {class_perf['f1_score']:.3f}")
        print(f"  ROC-AUC:           {class_perf['roc_auc']:.3f}")
        print(f"  Average Precision: {class_perf['average_precision']:.3f}")
        
        # Add special emphasis for chosen configuration
        if k == 3:
            print("\n" + ">" * 80)
            print(">>> THIS IS THE CHOSEN CONFIGURATION FOR FINAL MODEL <<<")
            print(">" * 80)
        
        print()
    else:
        print(f"K = {k}: Results not found\n")

print(f"{'='*80}")
print("For parameter fine-tuning results across different configurations,")
print(f"see: {CLUSTERING_CONFIG['models_base_dir']}/k{{X}}/{{config_name}}/")
print(f"{'='*80}")
# Out:
# COMPREHENSIVE CLUSTERING ANALYSIS - CURRENT CONFIGURATION
# ================================================================================
# Total runtime: 345.30 seconds
#
# ================================================================================
# K = 2 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.166, Test=0.161
#   Adjusted Rand Index:    Train=-0.007, Test=-0.045
#   Normalized Mutual Info: Train=0.050, Test=0.046
#
# Classification Performance:
#   Accuracy:          0.662
#   Precision:         0.000
#   Recall:            0.000
#   F1-Score:          0.000
#   ROC-AUC:           0.579
#   Average Precision: 0.378
#
# ================================================================================
# K = 3 RESULTS (Current Configuration) (chosen one)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.014, Test=0.011
#   Adjusted Rand Index:    Train=0.180, Test=0.270
#   Normalized Mutual Info: Train=0.255, Test=0.308
#
# Classification Performance:
#   Accuracy:          0.835
#   Precision:         0.996
#   Recall:            0.514
#   F1-Score:          0.678
#   ROC-AUC:           0.782
#   Average Precision: 0.694
#
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>> THIS IS THE CHOSEN CONFIGURATION FOR FINAL MODEL <<<
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# ================================================================================
# K = 4 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.015, Test=0.013
#   Adjusted Rand Index:    Train=0.175, Test=0.252
#   Normalized Mutual Info: Train=0.241, Test=0.290
#
# Classification Performance:
#   Accuracy:          0.835
#   Precision:         0.996
#   Recall:            0.513
#   F1-Score:          0.678
#   ROC-AUC:           0.789
#   Average Precision: 0.706
#
# ================================================================================
# K = 5 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=-0.032, Test=-0.038
#   Adjusted Rand Index:    Train=0.231, Test=0.311
#   Normalized Mutual Info: Train=0.253, Test=0.301
#
# Classification Performance:
#   Accuracy:          0.856
#   Precision:         0.860
#   Recall:            0.685
#   F1-Score:          0.763
#   ROC-AUC:           0.838
#   Average Precision: 0.776
#
# ================================================================================
# K = 6 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.014, Test=0.014
#   Adjusted Rand Index:    Train=0.148, Test=0.226
#   Normalized Mutual Info: Train=0.225, Test=0.268
#
# Classification Performance:
#   Accuracy:          0.837
#   Precision:         0.993
#   Recall:            0.521
#   F1-Score:          0.683
#   ROC-AUC:           0.790
#   Average Precision: 0.703
#
# ================================================================================
# K = 7 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.004, Test=0.002
#   Adjusted Rand Index:    Train=0.109, Test=0.120
#   Normalized Mutual Info: Train=0.243, Test=0.254
#
# Classification Performance:
#   Accuracy:          0.833
#   Precision:         0.991
#   Recall:            0.511
#   F1-Score:          0.674
#   ROC-AUC:           0.857
#   Average Precision: 0.751
#
# ================================================================================
# K = 8 RESULTS (Current Configuration)
# ================================================================================
#
# Clustering Performance:
#   Silhouette Score:       Train=0.015, Test=0.008
#   Adjusted Rand Index:    Train=0.163, Test=0.249
#   Normalized Mutual Info: Train=0.257, Test=0.284
#
# Classification Performance:
#   Accuracy:          0.848
#   Precision:         0.898
#   Recall:            0.623
#   F1-Score:          0.735
#   ROC-AUC:           0.838
#   Average Precision: 0.756
#
# ================================================================================
# For parameter fine-tuning results across different configurations,
# see: models/kmeans/k{X}/{config_name}/
# ================================================================================

# %% [markdown]
# ## 6. BiLSTM Deep Learning Model
# This section trains a bidirectional LSTM using PyTorch for contextual spam detection.
#
# Steps:
# - Create and loads tokenized and padded sequences with corresponding labels and sources.
# - Trains multiple BiLSTM variants (basic, deep, attention-based) with early stopping and validation monitoring.
# - Evaluates final models on test data using accuracy, F1, ROC-AUC, and source-level breakdown.
# - Visualizes confusion matrices, ROC curves, and performance across different message sources.

# %%
run_lstm_preprocessing(
    input_dir="final_dataset",  # Input from shared preprocessing
    output_dir="preprocessed/lstm",  # Output directory for LSTM data
    vocab_size=10000,  # Vocabulary size
    max_length=None,  # Auto-determine from data (will cap at 128)
    min_freq=2,  # Minimum token frequency
)
# Out:
# STARTING BILSTM PREPROCESSING PIPELINE
# ============================================================
# ============================================================
# LOADING PREPROCESSED DATA FOR BILSTM
# ============================================================
# Loaded training data: 12,003 records
# Loaded test data: 3,212 records
#
# Applying LSTM-specific text cleaning...
#
# ========================================
# BUILDING VOCABULARY
# ========================================
# Building vocabulary...
# Vocabulary size: 10,000
# Total tokens processed: 1,301,127
# Unique tokens: 36,568
#
# ========================================
# CONVERTING TEXT TO SEQUENCES
# ========================================
# Creating LSTM dataset with max_length=128...
# Creating LSTM dataset with max_length=128...
#
# Analyzing sequence lengths...
# Sequence length statistics:
#   Mean: 61.7
#   Median: 48.0
#   25th percentile: 20.0
#   75th percentile: 116.0
#   95th percentile: 128.0
#   Max: 128
#   Suggested max_length: 128
# Using max_length: 128
#
# ========================================
# PADDING SEQUENCES
# ========================================
# Padded sequences to length: 128
#
# Creating PyTorch tensors...
# Created PyTorch tensors:
#   X shape: torch.Size([12003, 128])
#   y shape: torch.Size([12003])
# Created PyTorch tensors:
#   X shape: torch.Size([3212, 128])
#   y shape: torch.Size([3212])
# ============================================================
# SAVING LSTM PREPROCESSED DATA
# ============================================================
# LSTM preprocessed data saved to: preprocessed\lstm
# Files created:
#   - X_train.pt, y_train.pt (12,003 samples)
#   - X_test.pt, y_test.pt (3,212 samples)
#   - train_sources.pkl, test_sources.pkl
#   - vocab.pkl, vocab.json (10,000 tokens)
#   - lstm_metadata.json
#
# ============================================================
# BILSTM PREPROCESSING COMPLETED!
# ============================================================
# Vocabulary size: 10,000
# Max sequence length: 128
# Training samples: 12,003
# Test samples: 3,212
# Output directory: preprocessed/lstm
#
# Next steps:
#   1. Use the saved tensors for BiLSTM model training
#   2. Load vocab.pkl for text preprocessing during inference
#   3. Check lstm_metadata.json for preprocessing details
# True

# %%
data_dir = "preprocessed/lstm/"
output_dir = "models/lstm"
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model_configs = [
    {
        "name": "basic_bilstm",
        "config": {
            "embedding_dim": 128,
            "hidden_dims": [64],
            "dense_layers": [32],
            "dropout_rate": 0.3,
            "bidirectional": True,
            "use_attention": False,
        },
    },
    {
        "name": "deep_bilstm", # Best model so far (user should choose this one)
        "config": {
            "embedding_dim": 128,
            "hidden_dims": [128, 64],
            "dense_layers": [64, 32],
            "dropout_rate": 0.3,
            "bidirectional": True,
            "use_attention": False,
        },
    },
    {
        "name": "bilstm_attention",
        "config": {
            "embedding_dim": 128,
            "hidden_dims": [128],
            "dense_layers": [64, 32],
            "dropout_rate": 0.3,
            "bidirectional": True,
            "use_attention": True,
            "attention_dim": 64,
        },
    },
    {
        "name": "unidirectional_lstm",
        "config": {
            "embedding_dim": 128,
            "hidden_dims": [128, 64],
            "dense_layers": [64, 32],
            "dropout_rate": 0.3,
            "bidirectional": False,
            "use_attention": False,
        },
    },
]

# Training configuration
train_config = {
    "epochs": 500,
    "batch_size": 512,
    "learning_rate": 0.0001,
    "weight_decay": 1e-5,
    "early_stopping_patience": 10,
    "lr_patience": 3,
    "lr_factor": 0.5,
    "clip_grad_norm": 1.0,
    "print_every": 5,
}

# Run experiments
results = run_lstm_experiments(
    model_configs,
    train_config,
    data_dir=data_dir,
    output_dir=output_dir,
    device=device,
)
# Out:
# Starting LSTM Spam Detection Training Pipeline
# ============================================================
# Loading LSTM preprocessed data...
# Training data: torch.Size([12003, 128])
# Test data: torch.Size([3212, 128])
# Vocabulary size: 10000
# Training sources: ['email' 'mix_email_sms' 'sms' 'youtube']
# Test sources: ['email' 'mix_email_sms' 'sms' 'youtube']
#
# ==================================================
# Training basic_bilstm
# ==================================================
# Model config: {'embedding_dim': 128, 'hidden_dims': [64], 'dense_layers': [32], 'dropout_rate': 0.3, 'bidirectional': True, 'use_attention': False}
#
# Training model with validation split...
# Setting up stratified train-validation split based on source+label...
# Stratification groups found:
#   email_0.0: 2159 samples
#   email_1.0: 1163 samples
#   mix_email_sms_0.0: 2433 samples
#   mix_email_sms_1.0: 2479 samples
#   sms_0.0: 1481 samples
#   sms_1.0: 635 samples
#   youtube_0.0: 799 samples
#   youtube_1.0: 854 samples
# Train set: 9602 samples
# Validation set: 2401 samples
# Model architecture:
# LSTMModel(
#   (embedding): Embedding(10000, 128, padding_idx=0)
#   (lstm_layers): ModuleList(
#     (0): LSTM(128, 64, batch_first=True, bidirectional=True)
#   )
#   (dense_layers_list): ModuleList(
#     (0): Linear(in_features=128, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#   )
#   (output_layer): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Epoch 1/500: Train Loss: 0.6881, Val Loss: 0.6843
# Epoch 6/500: Train Loss: 0.6451, Val Loss: 0.6390
# Epoch 11/500: Train Loss: 0.5272, Val Loss: 0.5219
# Epoch 16/500: Train Loss: 0.3862, Val Loss: 0.3892
# Epoch 21/500: Train Loss: 0.2965, Val Loss: 0.2966
# Epoch 26/500: Train Loss: 0.2488, Val Loss: 0.2447
# Epoch 31/500: Train Loss: 0.2128, Val Loss: 0.2086
# Epoch 36/500: Train Loss: 0.1881, Val Loss: 0.1856
# Epoch 41/500: Train Loss: 0.1648, Val Loss: 0.1696
# Epoch 46/500: Train Loss: 0.1471, Val Loss: 0.1591
# Epoch 51/500: Train Loss: 0.1352, Val Loss: 0.1433
# Epoch 56/500: Train Loss: 0.1199, Val Loss: 0.1381
# Epoch 61/500: Train Loss: 0.1107, Val Loss: 0.1374
# Epoch 66/500: Train Loss: 0.1051, Val Loss: 0.1373
# Epoch 71/500: Train Loss: 0.1055, Val Loss: 0.1367
# Early stopping at epoch 74
# Training completed in 28.77 seconds
# Evaluating final LSTM model...
#
# Test Set Performance:
#   ACCURACY: 0.9449
#   PRECISION: 0.8817
#   RECALL: 0.9669
#   F1: 0.9223
#   ROC_AUC: 0.9898
#
# Test Performance by Source:
#   email: F1=0.8534, Accuracy=0.9208 (n=859)
#   mix_email_sms: F1=0.9794, Accuracy=0.9788 (n=1226)
#   sms: F1=0.8199, Accuracy=0.9437 (n=835)
#   youtube: F1=0.8776, Accuracy=0.8767 (n=292)
#
# Detailed Test Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.98      0.93      0.96      2125
#         Spam       0.88      0.97      0.92      1087
#
#     accuracy                           0.94      3212
#    macro avg       0.93      0.95      0.94      3212
# weighted avg       0.95      0.94      0.95      3212
#
# LSTM evaluation plots saved to: models\lstm\basic_bilstm\lstm_evaluation.png
#
# ==================================================
# Training deep_bilstm
# ==================================================
# Model config: {'embedding_dim': 128, 'hidden_dims': [128, 64], 'dense_layers': [64, 32], 'dropout_rate': 0.3, 'bidirectional': True, 'use_attention': False}
#
# Training model with validation split...
# Setting up stratified train-validation split based on source+label...
# Stratification groups found:
#   email_0.0: 2159 samples
#   email_1.0: 1163 samples
#   mix_email_sms_0.0: 2433 samples
#   mix_email_sms_1.0: 2479 samples
#   sms_0.0: 1481 samples
#   sms_1.0: 635 samples
#   youtube_0.0: 799 samples
#   youtube_1.0: 854 samples
# Train set: 9602 samples
# Validation set: 2401 samples
# Model architecture:
# LSTMModel(
#   (embedding): Embedding(10000, 128, padding_idx=0)
#   (lstm_layers): ModuleList(
#     (0): LSTM(128, 128, batch_first=True, dropout=0.3, bidirectional=True)
#     (1): LSTM(256, 64, batch_first=True, bidirectional=True)
#   )
#   (dense_layers_list): ModuleList(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#   )
#   (output_layer): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Epoch 1/500: Train Loss: 0.6960, Val Loss: 0.6946
# Epoch 6/500: Train Loss: 0.6341, Val Loss: 0.6144
# Epoch 11/500: Train Loss: 0.3207, Val Loss: 0.3074
# Epoch 16/500: Train Loss: 0.2302, Val Loss: 0.2098
# Epoch 21/500: Train Loss: 0.1836, Val Loss: 0.1652
# Epoch 26/500: Train Loss: 0.1458, Val Loss: 0.1455
# Epoch 31/500: Train Loss: 0.1245, Val Loss: 0.1251
# Epoch 36/500: Train Loss: 0.0976, Val Loss: 0.1107
# Epoch 41/500: Train Loss: 0.0820, Val Loss: 0.1052
# Epoch 46/500: Train Loss: 0.0736, Val Loss: 0.1067
# Epoch 51/500: Train Loss: 0.0583, Val Loss: 0.1006
# Epoch 56/500: Train Loss: 0.0504, Val Loss: 0.0991
# Epoch 61/500: Train Loss: 0.0456, Val Loss: 0.1058
# Epoch 66/500: Train Loss: 0.0469, Val Loss: 0.0972
# Epoch 71/500: Train Loss: 0.0464, Val Loss: 0.0966
# Epoch 76/500: Train Loss: 0.0487, Val Loss: 0.0990
# Early stopping at epoch 78
# Training completed in 85.77 seconds
# Evaluating final LSTM model...
#
# Test Set Performance:
#   ACCURACY: 0.9707
#   PRECISION: 0.9469
#   RECALL: 0.9678
#   F1: 0.9572
#   ROC_AUC: 0.9942
#
# Test Performance by Source:
#   email: F1=0.9499, Accuracy=0.9756 (n=859)
#   mix_email_sms: F1=0.9904, Accuracy=0.9902 (n=1226)
#   sms: F1=0.8619, Accuracy=0.9605 (n=835)
#   youtube: F1=0.9048, Accuracy=0.9041 (n=292)
#
# Detailed Test Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.98      0.97      0.98      2125
#         Spam       0.95      0.97      0.96      1087
#
#     accuracy                           0.97      3212
#    macro avg       0.97      0.97      0.97      3212
# weighted avg       0.97      0.97      0.97      3212
#
# LSTM evaluation plots saved to: models\lstm\deep_bilstm\lstm_evaluation.png
#
# ==================================================
# Training bilstm_attention
# ==================================================
# Model config: {'embedding_dim': 128, 'hidden_dims': [128], 'dense_layers': [64, 32], 'dropout_rate': 0.3, 'bidirectional': True, 'use_attention': True, 'attention_dim': 64}
#
# Training model with validation split...
# Setting up stratified train-validation split based on source+label...
# Stratification groups found:
#   email_0.0: 2159 samples
#   email_1.0: 1163 samples
#   mix_email_sms_0.0: 2433 samples
#   mix_email_sms_1.0: 2479 samples
#   sms_0.0: 1481 samples
#   sms_1.0: 635 samples
#   youtube_0.0: 799 samples
#   youtube_1.0: 854 samples
# Train set: 9602 samples
# Validation set: 2401 samples
# Model architecture:
# LSTMModel(
#   (embedding): Embedding(10000, 128, padding_idx=0)
#   (lstm_layers): ModuleList(
#     (0): LSTM(128, 128, batch_first=True, bidirectional=True)
#   )
#   (attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#   )
#   (attention_linear): Linear(in_features=256, out_features=64, bias=True)
#   (dense_layers_list): ModuleList(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#   )
#   (output_layer): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Epoch 1/500: Train Loss: 0.6925, Val Loss: 0.6911
# Epoch 6/500: Train Loss: 0.4951, Val Loss: 0.3803
# Epoch 11/500: Train Loss: 0.2814, Val Loss: 0.2391
# Epoch 16/500: Train Loss: 0.2173, Val Loss: 0.1969
# Epoch 21/500: Train Loss: 0.1750, Val Loss: 0.1654
# Epoch 26/500: Train Loss: 0.1485, Val Loss: 0.1451
# Epoch 31/500: Train Loss: 0.1262, Val Loss: 0.1283
# Epoch 36/500: Train Loss: 0.1029, Val Loss: 0.1183
# Epoch 41/500: Train Loss: 0.0908, Val Loss: 0.1112
# Epoch 46/500: Train Loss: 0.0747, Val Loss: 0.1107
# Epoch 51/500: Train Loss: 0.0626, Val Loss: 0.1109
# Epoch 56/500: Train Loss: 0.0596, Val Loss: 0.1094
# Early stopping at epoch 60
# Training completed in 129.59 seconds
# Evaluating final LSTM model...
#
# Test Set Performance:
#   ACCURACY: 0.9651
#   PRECISION: 0.9364
#   RECALL: 0.9623
#   F1: 0.9492
#   ROC_AUC: 0.9921
#
# Test Performance by Source:
#   email: F1=0.9224, Accuracy=0.9616 (n=859)
#   mix_email_sms: F1=0.9863, Accuracy=0.9861 (n=1226)
#   sms: F1=0.8607, Accuracy=0.9593 (n=835)
#   youtube: F1=0.9034, Accuracy=0.9041 (n=292)
#
# Detailed Test Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.98      0.97      0.97      2125
#         Spam       0.94      0.96      0.95      1087
#
#     accuracy                           0.97      3212
#    macro avg       0.96      0.96      0.96      3212
# weighted avg       0.97      0.97      0.97      3212
#
# LSTM evaluation plots saved to: models\lstm\bilstm_attention\lstm_evaluation.png
#
# ==================================================
# Training unidirectional_lstm
# ==================================================
# Model config: {'embedding_dim': 128, 'hidden_dims': [128, 64], 'dense_layers': [64, 32], 'dropout_rate': 0.3, 'bidirectional': False, 'use_attention': False}
#
# Training model with validation split...
# Setting up stratified train-validation split based on source+label...
# Stratification groups found:
#   email_0.0: 2159 samples
#   email_1.0: 1163 samples
#   mix_email_sms_0.0: 2433 samples
#   mix_email_sms_1.0: 2479 samples
#   sms_0.0: 1481 samples
#   sms_1.0: 635 samples
#   youtube_0.0: 799 samples
#   youtube_1.0: 854 samples
# Train set: 9602 samples
# Validation set: 2401 samples
# Model architecture:
# LSTMModel(
#   (embedding): Embedding(10000, 128, padding_idx=0)
#   (lstm_layers): ModuleList(
#     (0): LSTM(128, 128, batch_first=True, dropout=0.3)
#     (1): LSTM(128, 64, batch_first=True)
#   )
#   (dense_layers_list): ModuleList(
#     (0): Linear(in_features=64, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=32, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.3, inplace=False)
#   )
#   (output_layer): Linear(in_features=32, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (dropout): Dropout(p=0.3, inplace=False)
# )
# Epoch 1/500: Train Loss: 0.6876, Val Loss: 0.6872
# Epoch 6/500: Train Loss: 0.6833, Val Loss: 0.6824
# Epoch 11/500: Train Loss: 0.6636, Val Loss: 0.6550
# Epoch 16/500: Train Loss: 0.5704, Val Loss: 0.5528
# Epoch 21/500: Train Loss: 0.5548, Val Loss: 0.5338
# Epoch 26/500: Train Loss: 0.5502, Val Loss: 0.5240
# Epoch 31/500: Train Loss: 0.5207, Val Loss: 0.5152
# Epoch 36/500: Train Loss: 0.5248, Val Loss: 0.5104
# Epoch 41/500: Train Loss: 0.5052, Val Loss: 0.4992
# Epoch 46/500: Train Loss: 0.5049, Val Loss: 0.5100
# Epoch 51/500: Train Loss: 0.5083, Val Loss: 0.5078
# Early stopping at epoch 51
# Training completed in 30.58 seconds
# Evaluating final LSTM model...
#
# Test Set Performance:
#   ACCURACY: 0.6385
#   PRECISION: 0.4831
#   RECALL: 0.9752
#   F1: 0.6461
#   ROC_AUC: 0.8048
#
# Test Performance by Source:
#   email: F1=0.7176, Accuracy=0.8324 (n=859)
#   mix_email_sms: F1=0.8758, Accuracy=0.8573 (n=1226)
#   sms: F1=0.2427, Accuracy=0.1629 (n=835)
#   youtube: F1=0.6743, Accuracy=0.5103 (n=292)
#
# Detailed Test Set Classification Report:
#               precision    recall  f1-score   support
#
#          Ham       0.97      0.47      0.63      2125
#         Spam       0.48      0.98      0.65      1087
#
#     accuracy                           0.64      3212
#    macro avg       0.73      0.72      0.64      3212
# weighted avg       0.81      0.64      0.64      3212
#
# LSTM evaluation plots saved to: models\lstm\unidirectional_lstm\lstm_evaluation.png
#
# ============================================================
# EXPERIMENT SUMMARY
# ============================================================
#
# basic_bilstm:
#   Test F1: 0.9223
#   Test Accuracy: 0.9449
#   Test Precision: 0.8817
#   Test Recall: 0.9669
#   Test ROC-AUC: 0.9898
#
# deep_bilstm:
#   Test F1: 0.9572
#   Test Accuracy: 0.9707
#   Test Precision: 0.9469
#   Test Recall: 0.9678
#   Test ROC-AUC: 0.9942
#
# bilstm_attention:
#   Test F1: 0.9492
#   Test Accuracy: 0.9651
#   Test Precision: 0.9364
#   Test Recall: 0.9623
#   Test ROC-AUC: 0.9921
#
# unidirectional_lstm:
#   Test F1: 0.6461
#   Test Accuracy: 0.6385
#   Test Precision: 0.4831
#   Test Recall: 0.9752
#   Test ROC-AUC: 0.8048

# %% [markdown]
# ## 7. Load and Inference text with all models

# %%
# List of input texts
input_texts = [
    "win a free prize!!! Only 1 chance :D",
    "how r u today?"
]

# %%
# XGB
xgb = XGBTextClassifier(model_dir="models/xgboost")
pred = xgb.predict(input_texts)

pred
# Out:
# Extracting text statistics...
# Extracting special character features...
# Extracting source features...
# array([1, 0])

# %%
# KMeans
kmeans = KMeansTextInferencer(model_dir="models/kmeans/k3/tfidf_1000")
pred = kmeans.predict(input_texts)

pred
# Out:
# Extracting comprehensive text features...
# Extracted 53 comprehensive text features per sample
# array([0, 0])

# %%
lstm = LSTMTextClassifier(model_dir="models/lstm/deep_bilstm_chosen")
pred = lstm.predict(input_texts)

pred
# Out:
# array([1, 0])
